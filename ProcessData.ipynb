# %%
import tensorflow as tf
AUTOTUNE = tf.data.experimental.AUTOTUNE

import IPython.display as display
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

import pandas as pd

tf.__version__
# Out:
# '1.15.2'

# %%
import zipfile
with zipfile.ZipFile('./augmented_data.zip', 'r') as zip_ref:
    zip_ref.extractall('./')

# %%
from PIL import Image
import pandas as pd
import glob
image_list = []
for filepath in glob.glob('./augmented_data/*/*.png', recursive=True): #assuming gif
    filename = filepath.split("/")[-1]
    label = filepath.split("/")[-2]
#     print(filepath, filename, label)
    image_list.append((filepath, label))
#     print(filepath, label)
    
# Create a data frame
data = pd.DataFrame(data=image_list, columns=['image_path', 'label'])
# Out:
#   File "<ipython-input-32-6ac9d01b1c0d>", line 9
#     image_list.append((fr_inx = np.random.choice(2000, 4)
#                               ^
# SyntaxError: invalid syntax

# %%
r_inx = np.random.choice(2000, 4)
rand_data = data.loc[r_inx,'image_path']

plt.figure(figsize=(16,4))
for i, image_path in enumerate(rand_data):
    im = np.asarray(Image.open(image_path))
    plt.subplot(1,4,i+1)
    plt.imshow(im,cmap='gray')
    plt.axis('off')
    
plt.show()

# %%
data
# Out:
#                                          image_path     label
# 0              ./augmented_data/hex/hex1_0_5459.png       hex
# 1              ./augmented_data/hex/hex6_0_6304.png       hex
# 2              ./augmented_data/hex/hex2_0_8721.png       hex
# 3              ./augmented_data/hex/hex6_0_1245.png       hex
# 4              ./augmented_data/hex/00554_00000.png       hex
# 5              ./augmented_data/hex/hex6_0_5781.png       hex
# 6              ./augmented_data/hex/hex5_0_3667.png       hex
# 7              ./augmented_data/hex/hex3_0_9286.png       hex
# 8              ./augmented_data/hex/hex4_0_3368.png       hex
# 9              ./augmented_data/hex/00685_00000.png       hex
# 10             ./augmented_data/hex/hex6_0_1010.png       hex
# 11             ./augmented_data/hex/hex4_0_1266.png       hex
# 12             ./augmented_data/hex/hex2_0_3005.png       hex
# 13             ./augmented_data/hex/hex4_0_4855.png       hex
# 14             ./augmented_data/hex/hex5_0_2394.png       hex
# 15              ./augmented_data/hex/hex6_0_458.png       hex
# 16              ./augmented_data/hex/hex1_0_816.png       hex
# 17             ./augmented_data/hex/hex4_0_7165.png       hex
# 18             ./augmented_data/hex/hex6_0_8543.png       hex
# 19             ./augmented_data/hex/hex3_0_8185.png       hex
# 20             ./augmented_data/hex/hex1_0_5313.png       hex
# 21             ./augmented_data/hex/hex4_0_4634.png       hex
# 22             ./augmented_data/hex/hex2_0_3232.png       hex
# 23             ./augmented_data/hex/hex4_0_9276.png       hex
# 24              ./augmented_data/hex/hex1_0_282.png       hex
# 25             ./augmented_data/hex/hex4_0_8231.png       hex
# 26             ./augmented_data/hex/hex5_0_4322.png       hex
# 27             ./augmented_data/hex/hex1_0_3353.png       hex
# 28             ./augmented_data/hex/hex1_0_4746.png       hex
# 29             ./augmented_data/hex/hex5_0_3896.png       hex
# ...                                             ...       ...
# 4823      ./augmented_data/triangle/00877_00000.png  triangle
# 4824      ./augmented_data/triangle/00307_00002.png  triangle
# 4825      ./augmented_data/triangle/01720_00002.png  triangle
# 4826      ./augmented_data/triangle/01423_00001.png  triangle
# 4827      ./augmented_data/triangle/00257_00002.png  triangle
# 4828      ./augmented_data/triangle/01531_00002.png  triangle
# 4829      ./augmented_data/triangle/00240_00002.png  triangle
# 4830      ./augmented_data/triangle/00058_00000.png  triangle
# 4831      ./augmented_data/triangle/00736_00001.png  triangle
# 4832      ./augmented_data/triangle/00023_00000.png  triangle
# 4833  ./augmented_data/triangle/triangle1_0_511.png  triangle
# 4834      ./augmented_data/triangle/01028_00000.png  triangle
# 4835      ./augmented_data/triangle/00689_00003.png  triangle
# 4836      ./augmented_data/triangle/00002_00002.png  triangle
# 4837      ./augmented_data/triangle/00235_00001.png  triangle
# 4838      ./augmented_data/triangle/00253_00000.png  triangle
# 4839      ./augmented_data/triangle/00057_00001.png  triangle
# 4840      ./augmented_data/triangle/00729_00002.png  triangle
# 4841      ./augmented_data/triangle/01203_00002.png  triangle
# 4842      ./augmented_data/triangle/01349_00000.png  triangle
# 4843      ./augmented_data/triangle/00017_00001.png  triangle
# 4844      ./augmented_data/triangle/00614_00002.png  triangle
# 4845      ./augmented_data/triangle/01720_00001.png  triangle
# 4846      ./augmented_data/triangle/00980_00000.png  triangle
# 4847      ./augmented_data/triangle/00920_00001.png  triangle
# 4848      ./augmented_data/triangle/01377_00001.png  triangle
# 4849      ./augmented_data/triangle/00675_00002.png  triangle
# 4850      ./augmented_data/triangle/00614_00000.png  triangle
# 4851      ./augmented_data/triangle/01433_00002.png  triangle
# 4852      ./augmented_data/triangle/01106_00000.png  triangle
#
# [4853 rows x 2 columns]

# %%
data.sample(frac=1)
# Out:
#                                             image_path     label
# 4370         ./augmented_data/triangle/01075_00000.png  triangle
# 783               ./augmented_data/hex/hex3_0_2103.png       hex
# 2845        ./augmented_data/square/square1_0_4158.png    square
# 1566            ./augmented_data/round/00019_00000.png     round
# 2446          ./augmented_data/diamond/00118_00001.png   diamond
# 571               ./augmented_data/hex/hex1_0_6716.png       hex
# 2563          ./augmented_data/diamond/01275_00001.png   diamond
# 3553        ./augmented_data/square/square3_0_8469.png    square
# 3388        ./augmented_data/square/square4_0_4613.png    square
# 3040           ./augmented_data/square/01116_00000.png    square
# 2262  ./augmented_data/diamond/aug_diamond4_0_8577.png   diamond
# 2732  ./augmented_data/diamond/aug_diamond3_0_6815.png   diamond
# 4653         ./augmented_data/triangle/00331_00002.png  triangle
# 746               ./augmented_data/hex/hex1_0_4207.png       hex
# 4145         ./augmented_data/triangle/01061_00002.png  triangle
# 575               ./augmented_data/hex/hex6_0_3953.png       hex
# 3685           ./augmented_data/square/01688_00000.png    square
# 3742           ./augmented_data/square/00456_00002.png    square
# 2943           ./augmented_data/square/01154_00002.png    square
# 2671  ./augmented_data/diamond/aug_diamond1_0_7744.png   diamond
# 2021     ./augmented_data/diamond/aug_diamond1_0_8.png   diamond
# 1184            ./augmented_data/round/00360_00002.png     round
# 2992           ./augmented_data/square/01573_00002.png    square
# 2535  ./augmented_data/diamond/aug_diamond3_0_3344.png   diamond
# 4837         ./augmented_data/triangle/00235_00001.png  triangle
# 886               ./augmented_data/hex/hex3_0_9263.png       hex
# 3174           ./augmented_data/square/01193_00003.png    square
# 4373         ./augmented_data/triangle/00987_00001.png  triangle
# 1531            ./augmented_data/round/00883_00000.png     round
# 791               ./augmented_data/hex/hex2_0_7880.png       hex
# ...                                                ...       ...
# 4017         ./augmented_data/triangle/00967_00001.png  triangle
# 4035         ./augmented_data/triangle/01888_00001.png  triangle
# 2249   ./augmented_data/diamond/aug_diamond4_0_702.png   diamond
# 2019   ./augmented_data/diamond/aug_diamond3_0_196.png   diamond
# 1710            ./augmented_data/round/00732_00002.png     round
# 219                ./augmented_data/hex/hex4_0_963.png       hex
# 3714        ./augmented_data/square/square2_0_8436.png    square
# 2542          ./augmented_data/diamond/00208_00002.png   diamond
# 4193         ./augmented_data/triangle/00710_00002.png  triangle
# 4127         ./augmented_data/triangle/00675_00001.png  triangle
# 3404           ./augmented_data/square/01021_00002.png    square
# 2861           ./augmented_data/square/01314_00000.png    square
# 1410            ./augmented_data/round/01606_00001.png     round
# 1934  ./augmented_data/diamond/aug_diamond3_0_2075.png   diamond
# 2648  ./augmented_data/diamond/aug_diamond1_0_6197.png   diamond
# 4646         ./augmented_data/triangle/00970_00001.png  triangle
# 523               ./augmented_data/hex/hex3_0_1274.png       hex
# 2990        ./augmented_data/square/square1_0_7811.png    square
# 4757         ./augmented_data/triangle/00390_00001.png  triangle
# 1868   ./augmented_data/diamond/aug_diamond4_0_167.png   diamond
# 238               ./augmented_data/hex/hex6_0_4665.png       hex
# 4484         ./augmented_data/triangle/01874_00001.png  triangle
# 3521           ./augmented_data/square/01068_00001.png    square
# 916               ./augmented_data/hex/hex5_0_1804.png       hex
# 4748         ./augmented_data/triangle/01397_00000.png  triangle
# 1898          ./augmented_data/diamond/01112_00002.png   diamond
# 471                ./augmented_data/hex/hex1_0_243.png       hex
# 3655           ./augmented_data/square/00106_00000.png    square
# 3746           ./augmented_data/square/01731_00000.png    square
# 3908         ./augmented_data/triangle/01101_00000.png  triangle
#
# [4853 rows x 2 columns]

# %%
# Convert string labels to numeric
# d = {'diamond':0, 'hex':1, 'square':2, 'triangle':3}
# data['labels_num'] = data['label'].map(d, na_action='ignore')

# Generate two data frames for training and validation
first_split = data.sample(frac=0.8).reset_index()
# print(first_split)
second_split= data.drop(first_split.index)
# print(second_split)

print('Train size: {}, Test size: {}'.format(first_split.shape[0], second_split.shape[0] ) )
N_train_images = first_split.shape[0]
N_val_images = second_split.shape[0]
# Out:
# Train size: 3882, Test size: 971

# %%
from sklearn.model_selection import train_test_split

train_df, validation_df = train_test_split(data, test_size=0.2)

# %%
# isinstance(train_df, pd.DataFrame)

# %%
batch_size = 16

# %%
def calculate_losses(model_in, data_generator_in, N_images, batch_size_):
    loss_hold = []
    acc_hold = []
    batches = 0
    
    # iterate over each batch
    for x,y in data_generator_in:
        loss, acc = model_in.evaluate(x, y, verbose=0)
        loss_hold.append(loss)
        acc_hold.append(acc)
        batches += 1
        if batches >= N_images / batch_size_:
            # we need to break the loop by hand because
            # the generator loops indefinitely
            break
            
    return np.mean(loss_hold), np.mean(acc_hold)

# %%
def train_model(model_, train_generator_in, validation_generator_in, num_epoch=50, verbose=False):
    res = []
    for e in range(num_epoch):
        # print('Epoch', e)
        batches = 0

        loss_ = []
        acc_ = []

         # iterate over each batch
        for x,y in train_generator_in:
            loss, acc = model_.train_on_batch(x, y) # Update weights and return train loss, acc per batch
            loss_.append(loss)
            acc_.append(acc)
            batches += 1
            if batches >= N_train_images / batch_size:
                # we need to break the loop by hand because
                # the generator loops indefinitely
                break
        loss_ = np.mean(loss_)
        acc_ = np.mean(acc_)

        loss, acc = calculate_losses(model_, validation_generator_in, N_val_images, batch_size)
        if verbose:
            print("Training epoch {}: Loss = {}, Accuracy = {}".format(e, loss_, acc_))
            print("Validation epoch {}: Loss = {}, Accuracy = {}".format(e, loss, acc))

        res.append((e, loss_, acc_, loss, acc))
    return np.asarray(res)

# %%
def plot_results(res):
    plt.figure(figsize=(12,4))
    plt.subplot(1,2,1)
    plt.plot(res[:,0], res[:,1], 'r-')
    plt.plot(res[:,0], res[:,3], 'b-')
    plt.legend(['Train', 'Validation'])
    plt.xlabel('epoch')
    plt.ylabel('Loss')
    plt.ylim([0, np.max([5., np.max(res[:,1]), np.max(res[:,3])])])

    plt.subplot(1,2,2)
    plt.plot(res[:,0], res[:,2], 'r-')
    plt.plot(res[:,0], res[:,4], 'b-')
    plt.legend(['Train', 'Validation'])
    plt.xlabel('epoch')
    plt.ylabel('Accuracy')
    plt.ylim([0, np.max([1., np.max(res[:,2]), np.max(res[:,4])])])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')
val_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

batch_size = 16

train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_df,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size,
        class_mode='categorical')

validation_generator = val_datagen.flow_from_dataframe(
        dataframe=validation_df,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size,
        class_mode='categorical')
# Out:
# Found 3882 validated image filenames belonging to 5 classes.
# Found 971 validated image filenames belonging to 5 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Lambda, Input
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.metrics import categorical_accuracy
from tensorflow.keras import regularizers, optimizers

model_cnn = Sequential()

# input
model_cnn.add(Input(shape=(28, 28, 3)))
model_cnn.add(Lambda(lambda x: tf.expand_dims(x[:,:,:,0], -1, name=None))) 
# this is a workaround. Dataloader automatically read one channel image as 3 channel 
#and we use Lambda layer to revert this back. Lambda layer can be used for operation 
#that does not involve trainianble weights

# Conv Layer 1
model_cnn.add(Conv2D(32, (3, 3),kernel_regularizer=regularizers.l2(0.001)))
model_cnn.add(Activation('relu'))
model_cnn.add(MaxPooling2D(pool_size=(2, 2)))

# Conv Layer 2 (no pooling)
model_cnn.add(Conv2D(32, (3, 3),kernel_regularizer=regularizers.l2(0.001)))
model_cnn.add(Activation('relu'))

# Conv Layer 3
model_cnn.add(Conv2D(64, (3, 3)))
model_cnn.add(Activation('relu'))
model_cnn.add(MaxPooling2D(pool_size=(2, 2)))

# MLP
model_cnn.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model_cnn.add(Dense(64))
model_cnn.add(Activation('relu'))
model_cnn.add(Dropout(0.5))
model_cnn.add(Dense(5))
model_cnn.add(Activation('softmax'))

sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model_cnn.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=[categorical_accuracy])

# save the weights so that we can start from the same place when tring different configurations
model_cnn.save_weights('model.h5')

model_cnn.summary()
# Out:
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:OMP_NUM_THREADS is no longer used by the default Keras config. To configure the number of threads, use tf.config.threading APIs.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda (Lambda)              (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# activation (Activation)      (None, 26, 26, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 11, 11, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 64)          18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 9, 9, 64)          0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                65600
# _________________________________________________________________
# activation_3 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 325
# _________________________________________________________________
# activation_4 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 93,989
# Trainable params: 93,989
# Non-trainable params: 0
# _________________________________________________________________

# %%
res = train_model(model_cnn, train_generator, validation_generator, num_epoch=50, verbose=1)
plot_results(res)
# Out:
# Training epoch 0: Loss = 1.610011100769043, Accuracy = 0.20026326179504395
# Validation epoch 0: Loss = 1.6079562921993067, Accuracy = 0.2145119160413742
# Training epoch 1: Loss = 1.61008882522583, Accuracy = 0.2067805975675583
# Validation epoch 1: Loss = 1.6083266324684269, Accuracy = 0.21106557548046112
# Training epoch 2: Loss = 1.6100404262542725, Accuracy = 0.20277206599712372
# Validation epoch 2: Loss = 1.6069245983342655, Accuracy = 0.2140461951494217
# Training epoch 3: Loss = 1.6099509000778198, Accuracy = 0.19896167516708374
# Validation epoch 3: Loss = 1.6075435935473832, Accuracy = 0.21497763693332672
# Training epoch 4: Loss = 1.6095322370529175, Accuracy = 0.2090877890586853
# Validation epoch 4: Loss = 1.6076759217215366, Accuracy = 0.21544335782527924
# Training epoch 5: Loss = 1.6098886728286743, Accuracy = 0.20327883958816528
# Validation epoch 5: Loss = 1.6080018790041815, Accuracy = 0.21497763693332672
# Training epoch 6: Loss = 1.6094202995300293, Accuracy = 0.20713494718074799
# Validation epoch 6: Loss = 1.608117787564387, Accuracy = 0.21153129637241364
# Training epoch 7: Loss = 1.6099023818969727, Accuracy = 0.2010745257139206
# Validation epoch 7: Loss = 1.6083794070071862, Accuracy = 0.21358047425746918
# Training epoch 8: Loss = 1.6098183393478394, Accuracy = 0.20349031686782837
# Validation epoch 8: Loss = 1.6084203544210216, Accuracy = 0.21358047425746918
# Training epoch 9: Loss = 1.6099140644073486, Accuracy = 0.1947988122701645
# Validation epoch 9: Loss = 1.607737527518976, Accuracy = 0.201192244887352
# Training epoch 10: Loss = 1.6098501682281494, Accuracy = 0.1995256096124649
# Validation epoch 10: Loss = 1.6074217890129714, Accuracy = 0.21292845904827118
# Training epoch 11: Loss = 1.6102935075759888, Accuracy = 0.20532502233982086
# Validation epoch 11: Loss = 1.6079592274837806, Accuracy = 0.201192244887352
# Training epoch 12: Loss = 1.6091324090957642, Accuracy = 0.21146166324615479
# Validation epoch 12: Loss = 1.6082053360391835, Accuracy = 0.2133941799402237
# Training epoch 13: Loss = 1.609985589981079, Accuracy = 0.1994227170944214
# Validation epoch 13: Loss = 1.6075924126828303, Accuracy = 0.21311475336551666
# Training epoch 14: Loss = 1.6093136072158813, Accuracy = 0.21259906888008118
# Validation epoch 14: Loss = 1.608785517880174, Accuracy = 0.21311475336551666
# Training epoch 15: Loss = 1.609431505203247, Accuracy = 0.20997561514377594
# Validation epoch 15: Loss = 1.6078360295686565, Accuracy = 0.20072652399539948
# Training epoch 16: Loss = 1.6101864576339722, Accuracy = 0.20045152306556702
# Validation epoch 16: Loss = 1.6079349517822266, Accuracy = 0.21246273815631866
# Training epoch 17: Loss = 1.609372854232788, Accuracy = 0.2096574455499649
# Validation epoch 17: Loss = 1.60830976337683, Accuracy = 0.21497763693332672
# Training epoch 18: Loss = 1.6100215911865234, Accuracy = 0.20857718586921692
# Validation epoch 18: Loss = 1.608188849980714, Accuracy = 0.2145119160413742
# Training epoch 19: Loss = 1.6098575592041016, Accuracy = 0.19160188734531403
# Validation epoch 19: Loss = 1.6071010867103201, Accuracy = 0.21544335782527924
# Training epoch 20: Loss = 1.6101855039596558, Accuracy = 0.2082170993089676
# Validation epoch 20: Loss = 1.6069967727192114, Accuracy = 0.21497763693332672
# Training epoch 21: Loss = 1.6095185279846191, Accuracy = 0.20307306945323944
# Validation epoch 21: Loss = 1.6083042856122627, Accuracy = 0.19821162521839142
# Training epoch 22: Loss = 1.6094601154327393, Accuracy = 0.20338743925094604
# Validation epoch 22: Loss = 1.6076321093762507, Accuracy = 0.2140461951494217
# Training epoch 23: Loss = 1.609548807144165, Accuracy = 0.21099869906902313
# Validation epoch 23: Loss = 1.607938500701404, Accuracy = 0.21358047425746918
# Training epoch 24: Loss = 1.6101906299591064, Accuracy = 0.20868578553199768
# Validation epoch 24: Loss = 1.607839611710095, Accuracy = 0.2140461951494217
# Training epoch 25: Loss = 1.609413981437683, Accuracy = 0.20107071101665497
# Validation epoch 25: Loss = 1.6079924731958108, Accuracy = 0.2140461951494217
# Training epoch 26: Loss = 1.6098378896713257, Accuracy = 0.20842477679252625
# Validation epoch 26: Loss = 1.6072113533489039, Accuracy = 0.2145119160413742
# Training epoch 27: Loss = 1.6096079349517822, Accuracy = 0.20405425131320953
# Validation epoch 27: Loss = 1.6083288700854192, Accuracy = 0.2133941799402237
# Training epoch 28: Loss = 1.6097667217254639, Accuracy = 0.21165409684181213
# Validation epoch 28: Loss = 1.6086388884997758, Accuracy = 0.21199701726436615
# Training epoch 29: Loss = 1.6103365421295166, Accuracy = 0.19392050802707672
# Validation epoch 29: Loss = 1.6074958805178032, Accuracy = 0.21199701726436615
# Training epoch 30: Loss = 1.6096670627593994, Accuracy = 0.20832762122154236
# Validation epoch 30: Loss = 1.609170708499971, Accuracy = 0.20026080310344696
# Training epoch 31: Loss = 1.6099045276641846, Accuracy = 0.20472107827663422
# Validation epoch 31: Loss = 1.6073285478060362, Accuracy = 0.2140461951494217
# Training epoch 32: Loss = 1.6092842817306519, Accuracy = 0.20024004578590393
# Validation epoch 32: Loss = 1.6091603412002813, Accuracy = 0.2140461951494217
# Training epoch 33: Loss = 1.6096490621566772, Accuracy = 0.19803383946418762
# Validation epoch 33: Loss = 1.6094875198895815, Accuracy = 0.20212368667125702
# Training epoch 34: Loss = 1.609928846359253, Accuracy = 0.20615379512310028
# Validation epoch 34: Loss = 1.6096192539715377, Accuracy = 0.21246273815631866
# Training epoch 35: Loss = 1.6097066402435303, Accuracy = 0.19016727805137634
# Validation epoch 35: Loss = 1.6069757449822348, Accuracy = 0.2140461951494217
# Training epoch 36: Loss = 1.6098213195800781, Accuracy = 0.1974184662103653
# Validation epoch 36: Loss = 1.6092206728262979, Accuracy = 0.21358047425746918
# Training epoch 37: Loss = 1.6097018718719482, Accuracy = 0.20287683606147766
# Validation epoch 37: Loss = 1.6085664307484862, Accuracy = 0.2145119160413742
# Training epoch 38: Loss = 1.6092363595962524, Accuracy = 0.21536731719970703
# Validation epoch 38: Loss = 1.6089157765028907, Accuracy = 0.21106557548046112
# Training epoch 39: Loss = 1.6106311082839966, Accuracy = 0.20297972857952118
# Validation epoch 39: Loss = 1.6070430122438024, Accuracy = 0.21497763693332672
# Training epoch 40: Loss = 1.6097956895828247, Accuracy = 0.2043057382106781
# Validation epoch 40: Loss = 1.6082923392780493, Accuracy = 0.20026080310344696
# Training epoch 41: Loss = 1.6096481084823608, Accuracy = 0.2069406360387802
# Validation epoch 41: Loss = 1.6074263131032225, Accuracy = 0.21358047425746918
# Training epoch 42: Loss = 1.6097354888916016, Accuracy = 0.19937318563461304
# Validation epoch 42: Loss = 1.607551959694409, Accuracy = 0.21199701726436615
# Training epoch 43: Loss = 1.6096397638320923, Accuracy = 0.20848003029823303
# Validation epoch 43: Loss = 1.6083136640611242, Accuracy = 0.2140461951494217
# Training epoch 44: Loss = 1.6102460622787476, Accuracy = 0.18867169320583344
# Validation epoch 44: Loss = 1.6078670122584358, Accuracy = 0.2140461951494217
# Training epoch 45: Loss = 1.6097359657287598, Accuracy = 0.19906453788280487
# Validation epoch 45: Loss = 1.6077328295004172, Accuracy = 0.21199701726436615
# Training epoch 46: Loss = 1.609595537185669, Accuracy = 0.20703208446502686
# Validation epoch 46: Loss = 1.6082097272403906, Accuracy = 0.21358047425746918
# Training epoch 47: Loss = 1.6094551086425781, Accuracy = 0.20667962729930878
# Validation epoch 47: Loss = 1.608199381437458, Accuracy = 0.19960878789424896
# Training epoch 48: Loss = 1.6095749139785767, Accuracy = 0.19911406934261322
# Validation epoch 48: Loss = 1.6087106466293335, Accuracy = 0.21497763693332672
# Training epoch 49: Loss = 1.6094365119934082, Accuracy = 0.20158322155475616
# Validation epoch 49: Loss = 1.6070788238869338, Accuracy = 0.2145119160413742

# %%
test_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

batch_size_t = 1

# Here the validation is used for testing and this should be changes to a separate test set.
test_generator = train_datagen.flow_from_dataframe(
        dataframe=validation_df,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size_t,
        class_mode='categorical')
# Out:
# Found 971 validated image filenames belonging to 5 classes.

# %%
d = {'diamond':0, 'hex':1, 'round':2, 'square':3, 'triangle':4}
data['labels_num'] = data['label'].map(d, na_action='ignore')

# %%
d_inv = {v: k for k, v in d.items()}
plt.figure(figsize=(16,4))
batches = 0
for x,y in test_generator:
        batches = batches + 1
        y_hat = model_cnn.predict(x, verbose=0)
        x = np.squeeze(x)
        if batches < 5:
            plt.subplot(1,5,batches)
            plt.imshow(x)
            plt.title("GT-{}, Pred-{}".format(d_inv[np.argmax(y[0])], d_inv[np.argmax(y_hat[0])] ))
            
        else:
            break
        
        plt.axis('off')

# %%
from PIL import Image
import pandas as pd
import glob
image_list = []
i = 0
for filepath in glob.glob('./chinese_traffic_sign/*/*.png', recursive=True): #assuming gif
    newsize = (28,28)
    img = Image.open(filepath).convert('L').resize(newsize)
    path = ('./chinese_processed_test_images/'+str(i)+'.png')
    img.save(path, 'png')
    filename = path
    label = filepath.split("/")[-2]
#     print(filepath, filename, label)
    image_list.append((filename, label))
    i = i + 1
    
# Create a data frame
chinese_test_data = pd.DataFrame(data=image_list, columns=['image_path', 'label'])

# %%
test_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

batch_size_t = 1

# Here the validation is used for testing and this should be changes to a separate test set.
test_generator = train_datagen.flow_from_dataframe(
        dataframe=chinese_test_data,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size_t,
        class_mode='categorical')
# Out:
# Found 102 validated image filenames belonging to 5 classes.

# %%
d = {'diamond':0, 'hex':1, 'round':2, 'square':3, 'triangle':4}
data['labels_num'] = data['label'].map(d, na_action='ignore')

# %%
d_inv = {v: k for k, v in d.items()}
plt.figure(figsize=(16,4))
batches = 0
for x,y in test_generator:
        batches = batches + 1
        y_hat = model_cnn.predict(x, verbose=0)
        x = np.squeeze(x)
        if batches < 5:
            plt.subplot(1,5,batches)
            plt.imshow(x)
            plt.title("GT-{}, Pred-{}".format(d_inv[np.argmax(y[0])], d_inv[np.argmax(y_hat[0])] ))
            
        else:
            break
        
        plt.axis('off')

# %%
res = train_model(model_cnn, train_generator, test_generator, num_epoch=50, verbose=1)
plot_results(res)
# Out:
# Training epoch 0: Loss = 1.609773874282837, Accuracy = 0.20013919472694397
# Validation epoch 0: Loss = 1.6115654452902373, Accuracy = 0.16393442451953888
# Training epoch 1: Loss = 1.6096171140670776, Accuracy = 0.2038428783416748
# Validation epoch 1: Loss = 1.6115260339174113, Accuracy = 0.14754098653793335
# Training epoch 2: Loss = 1.6097745895385742, Accuracy = 0.2119402140378952
# Validation epoch 2: Loss = 1.626629213817784, Accuracy = 0.1147540956735611
# Training epoch 3: Loss = 1.6100742816925049, Accuracy = 0.20268096029758453
# Validation epoch 3: Loss = 1.5952168194974055, Accuracy = 0.2950819730758667
# Training epoch 4: Loss = 1.610140085220337, Accuracy = 0.20501090586185455
# Validation epoch 4: Loss = 1.6109566375857494, Accuracy = 0.19672131538391113
# Training epoch 5: Loss = 1.6094006299972534, Accuracy = 0.20621520280838013
# Validation epoch 5: Loss = 1.6129467037857557, Accuracy = 0.21311475336551666
# Training epoch 6: Loss = 1.6100345849990845, Accuracy = 0.19902868568897247
# Validation epoch 6: Loss = 1.6110055681134834, Accuracy = 0.1803278625011444
# Training epoch 7: Loss = 1.6096794605255127, Accuracy = 0.20374605059623718
# Validation epoch 7: Loss = 1.6161880356366518, Accuracy = 0.2295081913471222
# Training epoch 8: Loss = 1.6095610857009888, Accuracy = 0.20192448794841766
# Validation epoch 8: Loss = 1.5991650194418234, Accuracy = 0.19672131538391113
# Training epoch 9: Loss = 1.6098605394363403, Accuracy = 0.2049231380224228
# Validation epoch 9: Loss = 1.61177324467018, Accuracy = 0.21311475336551666
# Training epoch 10: Loss = 1.6097548007965088, Accuracy = 0.2110505849123001
# Validation epoch 10: Loss = 1.6089087802855695, Accuracy = 0.21311475336551666
# Training epoch 11: Loss = 1.6098910570144653, Accuracy = 0.20304104685783386
# Validation epoch 11: Loss = 1.6199665890365351, Accuracy = 0.1803278625011444
# Training epoch 12: Loss = 1.6096733808517456, Accuracy = 0.20797930657863617
# Validation epoch 12: Loss = 1.6115992460094515, Accuracy = 0.13114753365516663
# Training epoch 13: Loss = 1.6091030836105347, Accuracy = 0.2094862014055252
# Validation epoch 13: Loss = 1.6000178681045283, Accuracy = 0.21311475336551666
# Training epoch 14: Loss = 1.6102063655853271, Accuracy = 0.2094862014055252
# Validation epoch 14: Loss = 1.6118879767714953, Accuracy = 0.2295081913471222
# Training epoch 15: Loss = 1.610202431678772, Accuracy = 0.19963689148426056
# Validation epoch 15: Loss = 1.615523078402535, Accuracy = 0.1803278625011444
# Training epoch 16: Loss = 1.6101176738739014, Accuracy = 0.1962055116891861
# Validation epoch 16: Loss = 1.6098202408337203, Accuracy = 0.24590164422988892
# Training epoch 17: Loss = 1.6099869012832642, Accuracy = 0.2104121446609497
# Validation epoch 17: Loss = 1.623433322202964, Accuracy = 0.14754098653793335
# Training epoch 18: Loss = 1.6099433898925781, Accuracy = 0.20379751920700073
# Validation epoch 18: Loss = 1.611399058435784, Accuracy = 0.1803278625011444
# Training epoch 19: Loss = 1.609670639038086, Accuracy = 0.1953401118516922
# Validation epoch 19: Loss = 1.608804081307083, Accuracy = 0.26229506731033325
# Training epoch 20: Loss = 1.609924077987671, Accuracy = 0.20512889325618744
# Validation epoch 20: Loss = 1.6110975331947452, Accuracy = 0.24590164422988892
# Training epoch 21: Loss = 1.6101099252700806, Accuracy = 0.20609720051288605
# Validation epoch 21: Loss = 1.6154683515673778, Accuracy = 0.1803278625011444
# Training epoch 22: Loss = 1.609904170036316, Accuracy = 0.20233599841594696
# Validation epoch 22: Loss = 1.6185588152682195, Accuracy = 0.13114753365516663
# Training epoch 23: Loss = 1.6097103357315063, Accuracy = 0.2048111855983734
# Validation epoch 23: Loss = 1.605150330262106, Accuracy = 0.24590164422988892
# Training epoch 24: Loss = 1.6088041067123413, Accuracy = 0.2038126438856125
# Validation epoch 24: Loss = 1.6188823610055643, Accuracy = 0.26229506731033325
# Training epoch 25: Loss = 1.6097826957702637, Accuracy = 0.19331881403923035
# Validation epoch 25: Loss = 1.6139710379428551, Accuracy = 0.14754098653793335
# Training epoch 26: Loss = 1.6099433898925781, Accuracy = 0.2087206393480301
# Validation epoch 26: Loss = 1.6094758451962081, Accuracy = 0.21311475336551666
# Training epoch 27: Loss = 1.6095367670059204, Accuracy = 0.20567962527275085
# Validation epoch 27: Loss = 1.6130703922177925, Accuracy = 0.2295081913471222
# Training epoch 28: Loss = 1.610163927078247, Accuracy = 0.2140129655599594
# Validation epoch 28: Loss = 1.6141857104223283, Accuracy = 0.19672131538391113
# Training epoch 29: Loss = 1.6098535060882568, Accuracy = 0.20021182298660278
# Validation epoch 29: Loss = 1.6084780673511694, Accuracy = 0.2295081913471222
# Training epoch 30: Loss = 1.6100393533706665, Accuracy = 0.1901809573173523
# Validation epoch 30: Loss = 1.6166686132305959, Accuracy = 0.16393442451953888
# Training epoch 31: Loss = 1.6093018054962158, Accuracy = 0.20204247534275055
# Validation epoch 31: Loss = 1.6073133808667543, Accuracy = 0.2295081913471222
# Training epoch 32: Loss = 1.6098062992095947, Accuracy = 0.2005355954170227
# Validation epoch 32: Loss = 1.6088887394451705, Accuracy = 0.1803278625011444
# Training epoch 33: Loss = 1.6095213890075684, Accuracy = 0.20842714607715607
# Validation epoch 33: Loss = 1.6115177205351532, Accuracy = 0.2295081913471222
# Training epoch 34: Loss = 1.6098055839538574, Accuracy = 0.2045539915561676
# Validation epoch 34: Loss = 1.618546124364509, Accuracy = 0.14754098653793335
# Training epoch 35: Loss = 1.610219955444336, Accuracy = 0.20029351115226746
# Validation epoch 35: Loss = 1.606905831665289, Accuracy = 0.1803278625011444
# Training epoch 36: Loss = 1.6097429990768433, Accuracy = 0.19434762001037598
# Validation epoch 36: Loss = 1.61728678374994, Accuracy = 0.19672131538391113
# Training epoch 37: Loss = 1.6093014478683472, Accuracy = 0.2173565775156021
# Validation epoch 37: Loss = 1.6175049719263295, Accuracy = 0.16393442451953888
# Training epoch 38: Loss = 1.6102372407913208, Accuracy = 0.19635982811450958
# Validation epoch 38: Loss = 1.6117853180306856, Accuracy = 0.16393442451953888
# Training epoch 39: Loss = 1.6093740463256836, Accuracy = 0.21181613206863403
# Validation epoch 39: Loss = 1.6058716246339142, Accuracy = 0.24590164422988892
# Training epoch 40: Loss = 1.6100785732269287, Accuracy = 0.19944022595882416
# Validation epoch 40: Loss = 1.6221583495374585, Accuracy = 0.16393442451953888
# Training epoch 41: Loss = 1.6097755432128906, Accuracy = 0.19566386938095093
# Validation epoch 41: Loss = 1.606923939751797, Accuracy = 0.26229506731033325
# Training epoch 42: Loss = 1.6097731590270996, Accuracy = 0.20665699243545532
# Validation epoch 42: Loss = 1.6126788600546416, Accuracy = 0.21311475336551666
# Training epoch 43: Loss = 1.6099170446395874, Accuracy = 0.20287157595157623
# Validation epoch 43: Loss = 1.6109752733199323, Accuracy = 0.14754098653793335
# Training epoch 44: Loss = 1.609858751296997, Accuracy = 0.2034071683883667
# Validation epoch 44: Loss = 1.609082878613081, Accuracy = 0.19672131538391113
# Training epoch 45: Loss = 1.609679937362671, Accuracy = 0.20489288866519928
# Validation epoch 45: Loss = 1.6216759955296751, Accuracy = 0.14754098653793335
# Training epoch 46: Loss = 1.6099579334259033, Accuracy = 0.20374001562595367
# Validation epoch 46: Loss = 1.6064501394991015, Accuracy = 0.26229506731033325
# Training epoch 47: Loss = 1.6095744371414185, Accuracy = 0.20235112309455872
# Validation epoch 47: Loss = 1.6157138425795758, Accuracy = 0.13114753365516663
# Training epoch 48: Loss = 1.6091794967651367, Accuracy = 0.21425503492355347
# Validation epoch 48: Loss = 1.6094048199106434, Accuracy = 0.19672131538391113
# Training epoch 49: Loss = 1.6093270778656006, Accuracy = 0.19909526407718658
# Validation epoch 49: Loss = 1.607955702015611, Accuracy = 0.14754098653793335

# %%
m1= model_cnn.fit_generator(
            test_generator,
            epochs=100,
            validation_data=validation_generator,
            class_weight = 'model.h5',
#             callbacks= Callbacks,
            verbose=False)

# %%
model_cnn.evaluate
