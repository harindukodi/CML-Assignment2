# %%
import tensorflow as tf
AUTOTUNE = tf.data.experimental.AUTOTUNE

import IPython.display as display
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

import pandas as pd

tf.__version__
# Out:
# '1.15.2'

# %%
import zipfile
with zipfile.ZipFile('./augmented_data.zip', 'r') as zip_ref:
    zip_ref.extractall('./')

# %%
from PIL import Image
import pandas as pd
import glob
image_list = []
for filepath in glob.glob('./augmented_data/*/*.png', recursive=True): #assuming gif
    filename = filepath.split("/")[-1]
    label = filepath.split("/")[-2]
#     print(filepath, filename, label)
    image_list.append((filepath, label))
    
# Create a data frame
data = pd.DataFrame(data=image_list, columns=['image_path', 'label'])

# %%
r_inx = np.random.choice(2000, 4)
rand_data = data.loc[r_inx,'image_path']

plt.figure(figsize=(16,4))
for i, image_path in enumerate(rand_data):
    im = np.asarray(Image.open(image_path))
    plt.subplot(1,4,i+1)
    plt.imshow(im,cmap='gray')
    plt.axis('off')
    
plt.show()

# %%
data
# Out:
#                                          image_path     label
# 0              ./augmented_data/hex/hex1_0_5459.png       hex
# 1              ./augmented_data/hex/hex6_0_6304.png       hex
# 2              ./augmented_data/hex/hex2_0_8721.png       hex
# 3              ./augmented_data/hex/hex6_0_1245.png       hex
# 4              ./augmented_data/hex/00554_00000.png       hex
# 5              ./augmented_data/hex/hex6_0_5781.png       hex
# 6              ./augmented_data/hex/hex5_0_3667.png       hex
# 7              ./augmented_data/hex/hex3_0_9286.png       hex
# 8              ./augmented_data/hex/hex4_0_3368.png       hex
# 9              ./augmented_data/hex/00685_00000.png       hex
# 10             ./augmented_data/hex/hex6_0_1010.png       hex
# 11             ./augmented_data/hex/hex4_0_1266.png       hex
# 12             ./augmented_data/hex/hex2_0_3005.png       hex
# 13             ./augmented_data/hex/hex4_0_4855.png       hex
# 14             ./augmented_data/hex/hex5_0_2394.png       hex
# 15              ./augmented_data/hex/hex6_0_458.png       hex
# 16              ./augmented_data/hex/hex1_0_816.png       hex
# 17             ./augmented_data/hex/hex4_0_7165.png       hex
# 18             ./augmented_data/hex/hex6_0_8543.png       hex
# 19             ./augmented_data/hex/hex3_0_8185.png       hex
# 20             ./augmented_data/hex/hex1_0_5313.png       hex
# 21             ./augmented_data/hex/hex4_0_4634.png       hex
# 22             ./augmented_data/hex/hex2_0_3232.png       hex
# 23             ./augmented_data/hex/hex4_0_9276.png       hex
# 24              ./augmented_data/hex/hex1_0_282.png       hex
# 25             ./augmented_data/hex/hex4_0_8231.png       hex
# 26             ./augmented_data/hex/hex5_0_4322.png       hex
# 27             ./augmented_data/hex/hex1_0_3353.png       hex
# 28             ./augmented_data/hex/hex1_0_4746.png       hex
# 29             ./augmented_data/hex/hex5_0_3896.png       hex
# ...                                             ...       ...
# 4823      ./augmented_data/triangle/00877_00000.png  triangle
# 4824      ./augmented_data/triangle/00307_00002.png  triangle
# 4825      ./augmented_data/triangle/01720_00002.png  triangle
# 4826      ./augmented_data/triangle/01423_00001.png  triangle
# 4827      ./augmented_data/triangle/00257_00002.png  triangle
# 4828      ./augmented_data/triangle/01531_00002.png  triangle
# 4829      ./augmented_data/triangle/00240_00002.png  triangle
# 4830      ./augmented_data/triangle/00058_00000.png  triangle
# 4831      ./augmented_data/triangle/00736_00001.png  triangle
# 4832      ./augmented_data/triangle/00023_00000.png  triangle
# 4833  ./augmented_data/triangle/triangle1_0_511.png  triangle
# 4834      ./augmented_data/triangle/01028_00000.png  triangle
# 4835      ./augmented_data/triangle/00689_00003.png  triangle
# 4836      ./augmented_data/triangle/00002_00002.png  triangle
# 4837      ./augmented_data/triangle/00235_00001.png  triangle
# 4838      ./augmented_data/triangle/00253_00000.png  triangle
# 4839      ./augmented_data/triangle/00057_00001.png  triangle
# 4840      ./augmented_data/triangle/00729_00002.png  triangle
# 4841      ./augmented_data/triangle/01203_00002.png  triangle
# 4842      ./augmented_data/triangle/01349_00000.png  triangle
# 4843      ./augmented_data/triangle/00017_00001.png  triangle
# 4844      ./augmented_data/triangle/00614_00002.png  triangle
# 4845      ./augmented_data/triangle/01720_00001.png  triangle
# 4846      ./augmented_data/triangle/00980_00000.png  triangle
# 4847      ./augmented_data/triangle/00920_00001.png  triangle
# 4848      ./augmented_data/triangle/01377_00001.png  triangle
# 4849      ./augmented_data/triangle/00675_00002.png  triangle
# 4850      ./augmented_data/triangle/00614_00000.png  triangle
# 4851      ./augmented_data/triangle/01433_00002.png  triangle
# 4852      ./augmented_data/triangle/01106_00000.png  triangle
#
# [4853 rows x 2 columns]

# %%
data.sample(frac=1)
# Out:
#                                             image_path     label
# 255               ./augmented_data/hex/hex1_0_1854.png       hex
# 2246   ./augmented_data/diamond/aug_diamond_0_3034.png   diamond
# 3806           ./augmented_data/square/01391_00000.png    square
# 1349            ./augmented_data/round/01639_00001.png     round
# 2499  ./augmented_data/diamond/aug_diamond4_0_2181.png   diamond
# 3877    ./augmented_data/triangle/triangle2_0_2751.png  triangle
# 2972           ./augmented_data/square/01898_00002.png    square
# 33                ./augmented_data/hex/hex3_0_6201.png       hex
# 1204            ./augmented_data/round/00744_00000.png     round
# 2874        ./augmented_data/square/square2_0_6809.png    square
# 4289         ./augmented_data/triangle/00623_00000.png  triangle
# 2326          ./augmented_data/diamond/01254_00000.png   diamond
# 658               ./augmented_data/hex/hex4_0_3045.png       hex
# 1059            ./augmented_data/round/00592_00000.png     round
# 2597  ./augmented_data/diamond/aug_diamond5_0_7441.png   diamond
# 1625            ./augmented_data/round/00707_00001.png     round
# 4723         ./augmented_data/triangle/01531_00000.png  triangle
# 3407           ./augmented_data/square/01554_00001.png    square
# 1096            ./augmented_data/round/01027_00002.png     round
# 2708  ./augmented_data/diamond/aug_diamond1_0_9314.png   diamond
# 1619            ./augmented_data/round/00905_00001.png     round
# 3269        ./augmented_data/square/square3_0_4515.png    square
# 3875         ./augmented_data/triangle/00960_00002.png  triangle
# 4539         ./augmented_data/triangle/00211_00000.png  triangle
# 2999        ./augmented_data/square/square1_0_1705.png    square
# 1058            ./augmented_data/round/01528_00000.png     round
# 3016           ./augmented_data/square/00043_00000.png    square
# 1133            ./augmented_data/round/00764_00000.png     round
# 4229         ./augmented_data/triangle/00243_00000.png  triangle
# 1550            ./augmented_data/round/00549_00000.png     round
# ...                                                ...       ...
# 1106            ./augmented_data/round/01890_00001.png     round
# 3155           ./augmented_data/square/01091_00001.png    square
# 3556           ./augmented_data/square/00615_00002.png    square
# 790               ./augmented_data/hex/hex2_0_6775.png       hex
# 2332          ./augmented_data/diamond/01894_00000.png   diamond
# 4438    ./augmented_data/triangle/triangle2_0_1932.png  triangle
# 2744  ./augmented_data/diamond/aug_diamond5_0_1153.png   diamond
# 4329         ./augmented_data/triangle/01077_00002.png  triangle
# 2400   ./augmented_data/diamond/aug_diamond_0_8379.png   diamond
# 1087            ./augmented_data/round/01356_00001.png     round
# 3176           ./augmented_data/square/00803_00001.png    square
# 1159            ./augmented_data/round/00653_00001.png     round
# 4198         ./augmented_data/triangle/01829_00000.png  triangle
# 1496            ./augmented_data/round/00171_00002.png     round
# 2939        ./augmented_data/square/square1_0_4962.png    square
# 3085           ./augmented_data/square/01410_00000.png    square
# 828               ./augmented_data/hex/hex1_0_3269.png       hex
# 3820           ./augmented_data/square/00670_00000.png    square
# 2669          ./augmented_data/diamond/01003_00000.png   diamond
# 3056        ./augmented_data/square/square4_0_8680.png    square
# 1067            ./augmented_data/round/00585_00002.png     round
# 2103   ./augmented_data/diamond/aug_diamond3_0_749.png   diamond
# 4284         ./augmented_data/triangle/01682_00002.png  triangle
# 1507            ./augmented_data/round/00588_00002.png     round
# 1358            ./augmented_data/round/00453_00000.png     round
# 2404  ./augmented_data/diamond/aug_diamond3_0_9312.png   diamond
# 4845         ./augmented_data/triangle/01720_00001.png  triangle
# 3362           ./augmented_data/square/00705_00002.png    square
# 4005         ./augmented_data/triangle/01640_00001.png  triangle
# 3395           ./augmented_data/square/00054_00002.png    square
#
# [4853 rows x 2 columns]

# %%
# Convert string labels to numeric
# d = {'diamond':0, 'hex':1, 'square':2, 'triangle':3}
# data['labels_num'] = data['label'].map(d, na_action='ignore')

# Generate two data frames for training and validation
first_split = data.sample(frac=0.8).reset_index()
# print(first_split)
second_split= data.drop(first_split.index)
# print(second_split)

print('Train size: {}, Test size: {}'.format(first_split.shape[0], second_split.shape[0] ) )
N_train_images = first_split.shape[0]
N_val_images = second_split.shape[0]
# Out:
# Train size: 3882, Test size: 971

# %%
from sklearn.model_selection import train_test_split

train_df, validation_df = train_test_split(data, test_size=0.2)

# %%
# isinstance(train_df, pd.DataFrame)

# %%
batch_size = 16

# %%
def calculate_losses(model_in, data_generator_in, N_images, batch_size_):
    loss_hold = []
    acc_hold = []
    batches = 0
    
    # iterate over each batch
    for x,y in data_generator_in:
        loss, acc = model_in.evaluate(x, y, verbose=0)
        loss_hold.append(loss)
        acc_hold.append(acc)
        batches += 1
        if batches >= N_images / batch_size_:
            # we need to break the loop by hand because
            # the generator loops indefinitely
            break
            
    return np.mean(loss_hold), np.mean(acc_hold)

# %%
def train_model(model_, train_generator_in, validation_generator_in, num_epoch=50, verbose=False):
    res = []
    for e in range(num_epoch):
        # print('Epoch', e)
        batches = 0

        loss_ = []
        acc_ = []

         # iterate over each batch
        for x,y in train_generator_in:
            loss, acc = model_.train_on_batch(x, y) # Update weights and return train loss, acc per batch
            loss_.append(loss)
            acc_.append(acc)
            batches += 1
            if batches >= N_train_images / batch_size:
                # we need to break the loop by hand because
                # the generator loops indefinitely
                break
        loss_ = np.mean(loss_)
        acc_ = np.mean(acc_)

        loss, acc = calculate_losses(model_, validation_generator_in, N_val_images, batch_size)
        if verbose:
            print("Training epoch {}: Loss = {}, Accuracy = {}".format(e, loss_, acc_))
            print("Validation epoch {}: Loss = {}, Accuracy = {}".format(e, loss, acc))

        res.append((e, loss_, acc_, loss, acc))
    return np.asarray(res)

# %%
def plot_results(res):
    plt.figure(figsize=(12,4))
    plt.subplot(1,2,1)
    plt.plot(res[:,0], res[:,1], 'r-')
    plt.plot(res[:,0], res[:,3], 'b-')
    plt.legend(['Train', 'Validation'])
    plt.xlabel('epoch')
    plt.ylabel('Loss')
    plt.ylim([0, np.max([5., np.max(res[:,1]), np.max(res[:,3])])])

    plt.subplot(1,2,2)
    plt.plot(res[:,0], res[:,2], 'r-')
    plt.plot(res[:,0], res[:,4], 'b-')
    plt.legend(['Train', 'Validation'])
    plt.xlabel('epoch')
    plt.ylabel('Accuracy')
    plt.ylim([0, np.max([1., np.max(res[:,2]), np.max(res[:,4])])])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')
val_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

batch_size = 16

train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_df,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size,
        class_mode='categorical')

validation_generator = val_datagen.flow_from_dataframe(
        dataframe=validation_df,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size,
        class_mode='categorical')
# Out:
# Found 3882 validated image filenames belonging to 5 classes.
# Found 971 validated image filenames belonging to 5 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Lambda, Input
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.metrics import categorical_accuracy
from tensorflow.keras import regularizers, optimizers

model_cnn = Sequential()

# input
model_cnn.add(Input(shape=(28, 28, 3)))
model_cnn.add(Lambda(lambda x: tf.expand_dims(x[:,:,:,0], -1, name=None))) 
# this is a workaround. Dataloader automatically read one channel image as 3 channel 
#and we use Lambda layer to revert this back. Lambda layer can be used for operation 
#that does not involve trainianble weights

# Conv Layer 1
model_cnn.add(Conv2D(32, (3, 3),kernel_regularizer=regularizers.l2(0.001)))
model_cnn.add(Activation('relu'))
model_cnn.add(MaxPooling2D(pool_size=(2, 2)))

# Conv Layer 2 (no pooling)
model_cnn.add(Conv2D(32, (3, 3),kernel_regularizer=regularizers.l2(0.001)))
model_cnn.add(Activation('relu'))

# Conv Layer 3
model_cnn.add(Conv2D(64, (3, 3)))
model_cnn.add(Activation('relu'))
model_cnn.add(MaxPooling2D(pool_size=(2, 2)))

# MLP
model_cnn.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model_cnn.add(Dense(64))
model_cnn.add(Activation('relu'))
model_cnn.add(Dropout(0.5))
model_cnn.add(Dense(5))
model_cnn.add(Activation('softmax'))

sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model_cnn.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=[categorical_accuracy])

# save the weights so that we can start from the same place when tring different configurations
model_cnn.save_weights('model.h5')

model_cnn.summary()
# Out:
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:OMP_NUM_THREADS is no longer used by the default Keras config. To configure the number of threads, use tf.config.threading APIs.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda (Lambda)              (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# activation (Activation)      (None, 26, 26, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 11, 11, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 64)          18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 9, 9, 64)          0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                65600
# _________________________________________________________________
# activation_3 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 325
# _________________________________________________________________
# activation_4 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 93,989
# Trainable params: 93,989
# Non-trainable params: 0
# _________________________________________________________________

# %%
res = train_model(model_cnn, train_generator, validation_generator, num_epoch=250, verbose=False)
plot_results(res)

# %%
test_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

batch_size_t = 1

# Here the validation is used for testing and this should be changes to a separate test set.
test_generator = train_datagen.flow_from_dataframe(
        dataframe=validation_df,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size_t,
        class_mode='categorical')
# Out:
# Found 971 validated image filenames belonging to 5 classes.

# %%
d = {'diamond':0, 'hex':1, 'round':2, 'square':3, 'triangle':4}
data['labels_num'] = data['label'].map(d, na_action='ignore')

# %%
d_inv = {v: k for k, v in d.items()}
plt.figure(figsize=(16,4))
batches = 0
for x,y in test_generator:
        batches = batches + 1
        y_hat = model_cnn.predict(x, verbose=0)
        x = np.squeeze(x)
        if batches < 5:
            plt.subplot(1,5,batches)
            plt.imshow(x)
            plt.title("GT-{}, Pred-{}".format(d_inv[np.argmax(y[0])], d_inv[np.argmax(y_hat[0])] ))
            
        else:
            break
        
        plt.axis('off')

# %%
from PIL import Image
import pandas as pd
import glob
image_list = []
for filepath in glob.glob('./processed_test_images/*.png', recursive=True): #assuming gif
    filename = filepath.split("/")[-1]
#     print(filepath)
#     print(filepath, filename, label)
    image_list.append((filepath))
    
# Create a data frame
test_data = pd.DataFrame(data=image_list, columns=['image_path'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
test_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

batch_size_t = 1

# Here the validation is used for testing and this should be changes to a separate test set.
test_generator = train_datagen.flow_from_dataframe(
        dataframe=test_data,
        directory='./',
        x_col="image_path",
        target_size=(28, 28))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'class'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-8771896c95c1> in <module>()
#       9         directory='./',
#      10         x_col="image_path",
# ---> 11         target_size=(28, 28))
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras_preprocessing/image/image_data_generator.py in flow_from_dataframe(self, dataframe, directory, x_col, y_col, weight_col, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, subset, interpolation, validate_filenames, **kwargs)
#     681             subset=subset,
#     682             interpolation=interpolation,
# --> 683             validate_filenames=validate_filenames
#     684         )
#     685
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras_preprocessing/image/dataframe_iterator.py in __init__(self, dataframe, directory, image_data_generator, x_col, y_col, weight_col, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, subset, interpolation, dtype, validate_filenames)
#     127         self.dtype = dtype
#     128         # check that inputs match the required class_mode
# --> 129         self._check_params(df, x_col, y_col, weight_col, classes)
#     130         if validate_filenames:  # check which image files are valid and keep them
#     131             df = self._filter_valid_filepaths(df, x_col)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras_preprocessing/image/dataframe_iterator.py in _check_params(self, df, x_col, y_col, weight_col, classes)
#     202         if self.class_mode == 'categorical':
#     203             types = (str, list, tuple)
# --> 204             if not all(df[y_col].apply(lambda x: isinstance(x, types))):
#     205                 raise TypeError('If class_mode="{}", y_col="{}" column '
#     206                                 'values must be type string, list or tuple.'
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'class'
