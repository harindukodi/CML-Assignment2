# %%
import tensorflow as tf
AUTOTUNE = tf.data.experimental.AUTOTUNE

import IPython.display as display
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

import pandas as pd

tf.__version__
# Out:
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow_core/__init__.py:1467: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
# '1.15.2'

# %%
import zipfile
with zipfile.ZipFile('./augmented_data.zip', 'r') as zip_ref:
    zip_ref.extractall('./')

# %%
from PIL import Image
import pandas as pd
import glob
image_list = []
for filepath in glob.glob('./augmented_data/*/*.png', recursive=True): #assuming gif
    filename = filepath.split("/")[-1]
    label = filepath.split("/")[-2]
#     print(filepath, filename, label)
    image_list.append((filepath, label))
#     print(filepath, label)
    
# Create a data frame
data = pd.DataFrame(data=image_list, columns=['image_path', 'label'])

# %%
r_inx = np.random.choice(2000, 4)
rand_data = data.loc[r_inx,'image_path']

plt.figure(figsize=(16,4))
for i, image_path in enumerate(rand_data):
    im = np.asarray(Image.open(image_path))
    plt.subplot(1,4,i+1)
    plt.imshow(im,cmap='gray')
    plt.axis('off')
    
plt.show()

# %%
data
# Out:
#                                          image_path     label
# 0              ./augmented_data/hex/hex1_0_5459.png       hex
# 1              ./augmented_data/hex/hex6_0_6304.png       hex
# 2              ./augmented_data/hex/hex2_0_8721.png       hex
# 3              ./augmented_data/hex/hex6_0_1245.png       hex
# 4              ./augmented_data/hex/00554_00000.png       hex
# 5              ./augmented_data/hex/hex6_0_5781.png       hex
# 6              ./augmented_data/hex/hex5_0_3667.png       hex
# 7              ./augmented_data/hex/hex3_0_9286.png       hex
# 8              ./augmented_data/hex/hex4_0_3368.png       hex
# 9              ./augmented_data/hex/00685_00000.png       hex
# 10             ./augmented_data/hex/hex6_0_1010.png       hex
# 11             ./augmented_data/hex/hex4_0_1266.png       hex
# 12             ./augmented_data/hex/hex2_0_3005.png       hex
# 13             ./augmented_data/hex/hex4_0_4855.png       hex
# 14             ./augmented_data/hex/hex5_0_2394.png       hex
# 15              ./augmented_data/hex/hex6_0_458.png       hex
# 16              ./augmented_data/hex/hex1_0_816.png       hex
# 17             ./augmented_data/hex/hex4_0_7165.png       hex
# 18             ./augmented_data/hex/hex6_0_8543.png       hex
# 19             ./augmented_data/hex/hex3_0_8185.png       hex
# 20             ./augmented_data/hex/hex1_0_5313.png       hex
# 21             ./augmented_data/hex/hex4_0_4634.png       hex
# 22             ./augmented_data/hex/hex2_0_3232.png       hex
# 23             ./augmented_data/hex/hex4_0_9276.png       hex
# 24              ./augmented_data/hex/hex1_0_282.png       hex
# 25             ./augmented_data/hex/hex4_0_8231.png       hex
# 26             ./augmented_data/hex/hex5_0_4322.png       hex
# 27             ./augmented_data/hex/hex1_0_3353.png       hex
# 28             ./augmented_data/hex/hex1_0_4746.png       hex
# 29             ./augmented_data/hex/hex5_0_3896.png       hex
# ...                                             ...       ...
# 4823      ./augmented_data/triangle/00877_00000.png  triangle
# 4824      ./augmented_data/triangle/00307_00002.png  triangle
# 4825      ./augmented_data/triangle/01720_00002.png  triangle
# 4826      ./augmented_data/triangle/01423_00001.png  triangle
# 4827      ./augmented_data/triangle/00257_00002.png  triangle
# 4828      ./augmented_data/triangle/01531_00002.png  triangle
# 4829      ./augmented_data/triangle/00240_00002.png  triangle
# 4830      ./augmented_data/triangle/00058_00000.png  triangle
# 4831      ./augmented_data/triangle/00736_00001.png  triangle
# 4832      ./augmented_data/triangle/00023_00000.png  triangle
# 4833  ./augmented_data/triangle/triangle1_0_511.png  triangle
# 4834      ./augmented_data/triangle/01028_00000.png  triangle
# 4835      ./augmented_data/triangle/00689_00003.png  triangle
# 4836      ./augmented_data/triangle/00002_00002.png  triangle
# 4837      ./augmented_data/triangle/00235_00001.png  triangle
# 4838      ./augmented_data/triangle/00253_00000.png  triangle
# 4839      ./augmented_data/triangle/00057_00001.png  triangle
# 4840      ./augmented_data/triangle/00729_00002.png  triangle
# 4841      ./augmented_data/triangle/01203_00002.png  triangle
# 4842      ./augmented_data/triangle/01349_00000.png  triangle
# 4843      ./augmented_data/triangle/00017_00001.png  triangle
# 4844      ./augmented_data/triangle/00614_00002.png  triangle
# 4845      ./augmented_data/triangle/01720_00001.png  triangle
# 4846      ./augmented_data/triangle/00980_00000.png  triangle
# 4847      ./augmented_data/triangle/00920_00001.png  triangle
# 4848      ./augmented_data/triangle/01377_00001.png  triangle
# 4849      ./augmented_data/triangle/00675_00002.png  triangle
# 4850      ./augmented_data/triangle/00614_00000.png  triangle
# 4851      ./augmented_data/triangle/01433_00002.png  triangle
# 4852      ./augmented_data/triangle/01106_00000.png  triangle
#
# [4853 rows x 2 columns]

# %%
#Randomizing the dataframe
data.sample(frac=1)
# Out:
#                                             image_path     label
# 1305            ./augmented_data/round/00099_00001.png     round
# 878               ./augmented_data/hex/hex5_0_8367.png       hex
# 2379          ./augmented_data/diamond/01894_00002.png   diamond
# 2677  ./augmented_data/diamond/aug_diamond5_0_2066.png   diamond
# 2296  ./augmented_data/diamond/aug_diamond2_0_2166.png   diamond
# 4787         ./augmented_data/triangle/00854_00000.png  triangle
# 2785   ./augmented_data/diamond/aug_diamond_0_7449.png   diamond
# 756               ./augmented_data/hex/hex2_0_8497.png       hex
# 3573           ./augmented_data/square/00183_00002.png    square
# 4800         ./augmented_data/triangle/01388_00002.png  triangle
# 15                 ./augmented_data/hex/hex6_0_458.png       hex
# 3658        ./augmented_data/square/square3_0_2914.png    square
# 3692           ./augmented_data/square/01362_00002.png    square
# 253               ./augmented_data/hex/hex6_0_6699.png       hex
# 4424         ./augmented_data/triangle/01344_00001.png  triangle
# 534               ./augmented_data/hex/hex1_0_7581.png       hex
# 2435  ./augmented_data/diamond/aug_diamond5_0_1406.png   diamond
# 1748            ./augmented_data/round/00453_00001.png     round
# 3018           ./augmented_data/square/01492_00001.png    square
# 2455          ./augmented_data/diamond/01231_00000.png   diamond
# 4244         ./augmented_data/triangle/00455_00002.png  triangle
# 1867   ./augmented_data/diamond/aug_diamond_0_7847.png   diamond
# 793               ./augmented_data/hex/00715_00001.png       hex
# 2998         ./augmented_data/square/square3_0_403.png    square
# 1346            ./augmented_data/round/01715_00000.png     round
# 4714         ./augmented_data/triangle/00970_00000.png  triangle
# 2033  ./augmented_data/diamond/aug_diamond3_0_5774.png   diamond
# 1808            ./augmented_data/round/00777_00001.png     round
# 1444            ./augmented_data/round/01894_00002.png     round
# 3331           ./augmented_data/square/01154_00000.png    square
# ...                                                ...       ...
# 2399   ./augmented_data/diamond/aug_diamond_0_3784.png   diamond
# 323               ./augmented_data/hex/hex4_0_6923.png       hex
# 2968           ./augmented_data/square/01477_00002.png    square
# 1832          ./augmented_data/diamond/00222_00001.png   diamond
# 3508           ./augmented_data/square/00471_00000.png    square
# 2896        ./augmented_data/square/square1_0_4135.png    square
# 1710            ./augmented_data/round/00732_00002.png     round
# 1027            ./augmented_data/round/00359_00000.png     round
# 4052         ./augmented_data/triangle/00202_00000.png  triangle
# 4006         ./augmented_data/triangle/01850_00002.png  triangle
# 121               ./augmented_data/hex/hex6_0_2498.png       hex
# 3394           ./augmented_data/square/00705_00001.png    square
# 3677           ./augmented_data/square/01637_00002.png    square
# 3625        ./augmented_data/square/square3_0_4927.png    square
# 222               ./augmented_data/hex/hex6_0_8257.png       hex
# 4707         ./augmented_data/triangle/00941_00000.png  triangle
# 4378         ./augmented_data/triangle/01604_00001.png  triangle
# 3895         ./augmented_data/triangle/00008_00000.png  triangle
# 3951         ./augmented_data/triangle/01205_00002.png  triangle
# 1240            ./augmented_data/round/01252_00000.png     round
# 4351         ./augmented_data/triangle/00263_00002.png  triangle
# 2479  ./augmented_data/diamond/aug_diamond1_0_6020.png   diamond
# 2999        ./augmented_data/square/square1_0_1705.png    square
# 1450            ./augmented_data/round/00800_00000.png     round
# 754               ./augmented_data/hex/01868_00002.png       hex
# 1118            ./augmented_data/round/01253_00002.png     round
# 2320  ./augmented_data/diamond/aug_diamond2_0_1887.png   diamond
# 3708        ./augmented_data/square/square1_0_5224.png    square
# 4634         ./augmented_data/triangle/01906_00001.png  triangle
# 859               ./augmented_data/hex/hex1_0_9192.png       hex
#
# [4853 rows x 2 columns]

# %%
# Convert string labels to numeric
# d = {'diamond':0, 'hex':1, 'square':2, 'triangle':3}
# data['labels_num'] = data['label'].map(d, na_action='ignore')

# Generate two data frames for training and validation
first_split = data.sample(frac=0.8).reset_index()
# print(first_split)
second_split= data.drop(first_split.index)
# print(second_split)

print('Train size: {}, Test size: {}'.format(first_split.shape[0], second_split.shape[0] ) )
N_train_images = first_split.shape[0]
N_val_images = second_split.shape[0]
# Out:
# Train size: 3882, Test size: 971

# %%
from sklearn.model_selection import train_test_split

train_df, validation_df = train_test_split(data, test_size=0.2)

# %%
# isinstance(train_df, pd.DataFrame)

# %%
batch_size = 16

# %%
def calculate_losses(model_in, data_generator_in, N_images, batch_size_):
    loss_hold = []
    acc_hold = []
    batches = 0
    
    # iterate over each batch
    for x,y in data_generator_in:
        loss, acc = model_in.evaluate(x, y, verbose=0)
        loss_hold.append(loss)
        acc_hold.append(acc)
        batches += 1
        if batches >= N_images / batch_size_:
            # we need to break the loop by hand because
            # the generator loops indefinitely
            break
            
    return np.mean(loss_hold), np.mean(acc_hold)

# %%
def train_model(model_, train_generator_in, validation_generator_in, num_epoch=50, verbose=False):
    res = []
    for e in range(num_epoch):
        # print('Epoch', e)
        batches = 0

        loss_ = []
        acc_ = []

         # iterate over each batch
        for x,y in train_generator_in:
            loss, acc = model_.train_on_batch(x, y) # Update weights and return train loss, acc per batch
            loss_.append(loss)
            acc_.append(acc)
            batches += 1
            if batches >= N_train_images / batch_size:
                # we need to break the loop by hand because
                # the generator loops indefinitely
                break
        loss_ = np.mean(loss_)
        acc_ = np.mean(acc_)

        loss, acc = calculate_losses(model_, validation_generator_in, N_val_images, batch_size)
        if verbose:
            print("Training epoch {}: Loss = {}, Accuracy = {}".format(e, loss_, acc_))
            print("Validation epoch {}: Loss = {}, Accuracy = {}".format(e, loss, acc))

        res.append((e, loss_, acc_, loss, acc))
    return np.asarray(res)

# %%
def plot_results(res):
    plt.figure(figsize=(12,4))
    plt.subplot(1,2,1)
    plt.plot(res[:,0], res[:,1], 'r-')
    plt.plot(res[:,0], res[:,3], 'b-')
    plt.legend(['Train', 'Validation'])
    plt.xlabel('epoch')
    plt.ylabel('Loss')
    plt.ylim([0, np.max([5., np.max(res[:,1]), np.max(res[:,3])])])

    plt.subplot(1,2,2)
    plt.plot(res[:,0], res[:,2], 'r-')
    plt.plot(res[:,0], res[:,4], 'b-')
    plt.legend(['Train', 'Validation'])
    plt.xlabel('epoch')
    plt.ylabel('Accuracy')
    plt.ylim([0, np.max([1., np.max(res[:,2]), np.max(res[:,4])])])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')
val_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

batch_size = 16

train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_df,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size,
        class_mode='categorical')

validation_generator = val_datagen.flow_from_dataframe(
        dataframe=validation_df,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size,
        class_mode='categorical')
# Out:
# Found 3882 validated image filenames belonging to 5 classes.
# Found 971 validated image filenames belonging to 5 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Lambda, Input
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.metrics import categorical_accuracy
from tensorflow.keras import regularizers, optimizers

model_cnn = Sequential()

# input
model_cnn.add(Input(shape=(28, 28, 3)))
model_cnn.add(Lambda(lambda x: tf.expand_dims(x[:,:,:,0], -1, name=None))) 
# this is a workaround. Dataloader automatically read one channel image as 3 channel 
#and we use Lambda layer to revert this back. Lambda layer can be used for operation 
#that does not involve trainianble weights

# Conv Layer 1
model_cnn.add(Conv2D(32, (3, 3),kernel_regularizer=regularizers.l2(0.001)))
model_cnn.add(Activation('relu'))
model_cnn.add(MaxPooling2D(pool_size=(2, 2)))

# Conv Layer 2 (no pooling)
model_cnn.add(Conv2D(32, (3, 3),kernel_regularizer=regularizers.l2(0.001)))
model_cnn.add(Activation('relu'))

# Conv Layer 3
model_cnn.add(Conv2D(64, (3, 3)))
model_cnn.add(Activation('relu'))
model_cnn.add(MaxPooling2D(pool_size=(2, 2)))

# Conv Layer 4
model_cnn.add(Conv2D(64, (3, 3)))
model_cnn.add(Activation('relu'))
model_cnn.add(MaxPooling2D(pool_size=(2, 2)))

# MLP
model_cnn.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model_cnn.add(Dense(64))
model_cnn.add(Activation('relu'))
model_cnn.add(Dropout(0.5))
model_cnn.add(Dense(5))
model_cnn.add(Activation('softmax'))

sgd = optimizers.SGD(lr=0.03, decay=1e-6, momentum=0.8, nesterov=True)
model_cnn.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=[categorical_accuracy])

# save the weights so that we can start from the same place when tring different configurations
model_cnn.save_weights('model2.h5')

model_cnn.summary()
# Out:
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:OMP_NUM_THREADS is no longer used by the default Keras config. To configure the number of threads, use tf.config.threading APIs.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda (Lambda)              (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# activation (Activation)      (None, 26, 26, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 11, 11, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 64)          18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 9, 9, 64)          0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 2, 2, 64)          36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 2, 2, 64)          0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 325
# _________________________________________________________________
# activation_5 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 69,477
# Trainable params: 69,477
# Non-trainable params: 0
# _________________________________________________________________

# %%
res = train_model(model_cnn, train_generator, validation_generator, num_epoch=100, verbose=1)
plot_results(res)
# Out:
# Training epoch 0: Loss = 1.6450868844985962, Accuracy = 0.2052469104528427
# Validation epoch 0: Loss = 1.6485315991229699, Accuracy = 0.20938897132873535
# Training epoch 1: Loss = 1.6396658420562744, Accuracy = 0.2062128484249115
# Validation epoch 1: Loss = 1.6375568597043146, Accuracy = 0.21097242832183838
# Training epoch 2: Loss = 1.6368451118469238, Accuracy = 0.20379896461963654
# Validation epoch 2: Loss = 1.6335196143291035, Accuracy = 0.20892325043678284
# Training epoch 84: Loss = 1.6100112199783325, Accuracy = 0.20605851709842682
# Validation epoch 84: Loss = 1.609918013947909, Accuracy = 0.21004098653793335
# Training epoch 85: Loss = 1.6098328828811646, Accuracy = 0.2110501527786255
# Validation epoch 85: Loss = 1.6128408674333916, Accuracy = 0.18647541105747223
# Training epoch 86: Loss = 1.6096711158752441, Accuracy = 0.2123456746339798
# Validation epoch 86: Loss = 1.6100332697883981, Accuracy = 0.18740685284137726
# Training epoch 87: Loss = 1.609384536743164, Accuracy = 0.20394566655158997
# Validation epoch 87: Loss = 1.6145527734131109, Accuracy = 0.2079918086528778
# Training epoch 88: Loss = 1.6101677417755127, Accuracy = 0.20380087196826935
# Validation epoch 88: Loss = 1.6099203805454443, Accuracy = 0.20892325043678284
# Training epoch 89: Loss = 1.6096733808517456, Accuracy = 0.2150624841451645
# Validation epoch 89: Loss = 1.613563660715447, Accuracy = 0.18694113194942474
# Training epoch 90: Loss = 1.6099519729614258, Accuracy = 0.19294504821300507
# Validation epoch 90: Loss = 1.6107623889798024, Accuracy = 0.20845752954483032
# Training epoch 91: Loss = 1.608845829963684, Accuracy = 0.21413657069206238
# Validation epoch 91: Loss = 1.6114790635030778, Accuracy = 0.20938897132873535
# Training epoch 92: Loss = 1.609696626663208, Accuracy = 0.20446006953716278
# Validation epoch 92: Loss = 1.6116436485384331, Accuracy = 0.1883382946252823
# Training epoch 93: Loss = 1.6088907718658447, Accuracy = 0.2118636667728424
# Validation epoch 93: Loss = 1.6126855299121043, Accuracy = 0.18647541105747223
# Training epoch 94: Loss = 1.6096316576004028, Accuracy = 0.208533376455307
# Validation epoch 94: Loss = 1.613601893675132, Accuracy = 0.18740685284137726
# Training epoch 95: Loss = 1.6100223064422607, Accuracy = 0.2043609917163849
# Validation epoch 95: Loss = 1.6092176867313073, Accuracy = 0.20845752954483032
# Training epoch 96: Loss = 1.609742522239685, Accuracy = 0.2099698781967163
# Validation epoch 96: Loss = 1.612401397501836, Accuracy = 0.2079918086528778
# Training epoch 97: Loss = 1.6101199388504028, Accuracy = 0.20236243307590485
# Validation epoch 97: Loss = 1.6133760682872085, Accuracy = 0.18694113194942474
# Training epoch 98: Loss = 1.6094634532928467, Accuracy = 0.20991845428943634
# Validation epoch 98: Loss = 1.6109904617559714, Accuracy = 0.18647541105747223

# %%
test_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

batch_size_t = 1

# Here the validation is used for testing and this should be changes to a separate test set.
test_generator = train_datagen.flow_from_dataframe(
        dataframe=validation_df,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size_t,
        class_mode='categorical')
# Out:
# Found 971 validated image filenames belonging to 5 classes.

# %%
d = {'diamond':0, 'hex':1, 'round':2, 'square':3, 'triangle':4}
data['labels_num'] = data['label'].map(d, na_action='ignore')

# %%
d_inv = {v: k for k, v in d.items()}
plt.figure(figsize=(16,4))
batches = 0
for x,y in test_generator:
        batches = batches + 1
        y_hat = model_cnn.predict(x, verbose=0)
        x = np.squeeze(x)
        if batches < 5:
            plt.subplot(1,5,batches)
            plt.imshow(x)
            plt.title("GT-{}, Pred-{}".format(d_inv[np.argmax(y[0])], d_inv[np.argmax(y_hat[0])] ))
            
        else:
            break
        
        plt.axis('off')

# %%
from PIL import Image
import pandas as pd
import glob
image_list = []
i = 0
for filepath in glob.glob('./chinese_traffic_sign/*/*.png', recursive=True): #assuming gif
    newsize = (28,28)
    img = Image.open(filepath).convert('L').resize(newsize)
    path = ('./chinese_processed_test_images/'+str(i)+'.png')
    img.save(path, 'png')
    filename = path
    label = filepath.split("/")[-2]
#     print(filepath, filename, label)
    image_list.append((filename, label))
    i = i + 1
    
# Create a data frame
chinese_test_data = pd.DataFrame(data=image_list, columns=['image_path', 'label'])

# %%
test_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

batch_size_t = 1

# Here the validation is used for testing and this should be changes to a separate test set.
test_generator = train_datagen.flow_from_dataframe(
        dataframe=chinese_test_data,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size_t,
        class_mode='categorical')
# Out:
# Found 102 validated image filenames belonging to 5 classes.

# %%
d = {'diamond':0, 'hex':1, 'round':2, 'square':3, 'triangle':4}
data['labels_num'] = data['label'].map(d, na_action='ignore')

# %%
d_inv = {v: k for k, v in d.items()}
plt.figure(figsize=(16,4))
batches = 0
for x,y in test_generator:
        batches = batches + 1
        y_hat = model_cnn.predict(x, verbose=0)
        x = np.squeeze(x)
        if batches < 5:
            plt.subplot(1,5,batches)
            plt.imshow(x)
            plt.title("GT-{}, Pred-{}".format(d_inv[np.argmax(y[0])], d_inv[np.argmax(y_hat[0])] ))
            
        else:
            break
        
        plt.axis('off')

# %%
res = train_model(model_cnn, train_generator, test_generator, num_epoch=50, verbose=1)
plot_results(res)
# Out:
# Training epoch 0: Loss = 0.01902708038687706, Accuracy = 0.9992284178733826
# Validation epoch 0: Loss = 1.4743534218916883, Accuracy = 0.7213114500045776
# Training epoch 1: Loss = 0.019459014758467674, Accuracy = 0.9981995820999146
# Validation epoch 1: Loss = 1.3139061282129316, Accuracy = 0.7049180269241333
# Training epoch 2: Loss = 0.019602470099925995, Accuracy = 0.9984567761421204
# Validation epoch 2: Loss = 1.0879705322326207, Accuracy = 0.8032786846160889
# Training epoch 3: Loss = 0.016336781904101372, Accuracy = 0.9994856119155884
# Validation epoch 3: Loss = 1.0288524273782969, Accuracy = 0.7213114500045776
# Training epoch 4: Loss = 0.014915547333657742, Accuracy = 0.9994856119155884
# Validation epoch 4: Loss = 0.8839688376508287, Accuracy = 0.7868852615356445
# Training epoch 5: Loss = 0.0188404843211174, Accuracy = 0.9977003335952759
# Validation epoch 5: Loss = 1.188522536246503, Accuracy = 0.7540983557701111
# Training epoch 6: Loss = 0.019479727372527122, Accuracy = 0.9984567761421204
# Validation epoch 6: Loss = 1.0499285880445701, Accuracy = 0.7704917788505554
# Training epoch 7: Loss = 0.020420420914888382, Accuracy = 0.9979423880577087
# Validation epoch 7: Loss = 1.340473792118738, Accuracy = 0.7540983557701111
# Training epoch 8: Loss = 0.015820102766156197, Accuracy = 0.9992284178733826
# Validation epoch 8: Loss = 1.5300482550300047, Accuracy = 0.7540983557701111
# Training epoch 9: Loss = 0.01465273555368185, Accuracy = 0.9992435574531555
# Validation epoch 9: Loss = 1.707949203179508, Accuracy = 0.688524603843689
# Training epoch 10: Loss = 0.015377633273601532, Accuracy = 0.9987139701843262
# Validation epoch 10: Loss = 1.319804546804946, Accuracy = 0.7540983557701111
# Training epoch 31: Loss = 0.020178919658064842, Accuracy = 0.9979423880577087
# Validation epoch 31: Loss = 1.3513459035760311, Accuracy = 0.7540983557701111
# Training epoch 32: Loss = 0.054278526455163956, Accuracy = 0.9889403581619263
# Validation epoch 32: Loss = 1.2429529466345661, Accuracy = 0.7868852615356445
# Training epoch 33: Loss = 0.028913132846355438, Accuracy = 0.9948710799217224
# Validation epoch 33: Loss = 1.0697228609294187, Accuracy = 0.7377049326896667
# Training epoch 34: Loss = 0.02764192409813404, Accuracy = 0.9963991641998291
# Validation epoch 34: Loss = 1.3272963217230604, Accuracy = 0.7213114500045776
# Training epoch 35: Loss = 0.022405164316296577, Accuracy = 0.9981995820999146
# Validation epoch 35: Loss = 0.5235036279639749, Accuracy = 0.8360655903816223
# Training epoch 36: Loss = 0.018590357154607773, Accuracy = 0.9992284178733826
# Validation epoch 36: Loss = 2.244532999719997, Accuracy = 0.6721311211585999
# Training epoch 37: Loss = 0.04202857241034508, Accuracy = 0.9912703037261963
# Validation epoch 37: Loss = 2.6691087080684843, Accuracy = 0.6393442749977112
# Training epoch 38: Loss = 0.026460207998752594, Accuracy = 0.9969135522842407
# Validation epoch 38: Loss = 0.6469299701027206, Accuracy = 0.8360655903816223
# Training epoch 39: Loss = 0.025697309523820877, Accuracy = 0.9976851940155029
# Validation epoch 39: Loss = 1.2117080559923512, Accuracy = 0.7540983557701111
# Training epoch 40: Loss = 0.032347582280635834, Accuracy = 0.9948559403419495
# Validation epoch 40: Loss = 2.292384473942831, Accuracy = 0.6229507923126221
# Training epoch 41: Loss = 0.037165317684412, Accuracy = 0.9956427216529846
# Validation epoch 41: Loss = 0.8152254903536351, Accuracy = 0.8032786846160889
# Training epoch 42: Loss = 0.021400626748800278, Accuracy = 0.9988168478012085
# Validation epoch 42: Loss = 1.076438530180298, Accuracy = 0.7704917788505554
# Training epoch 43: Loss = 0.023654622957110405, Accuracy = 0.9984567761421204
# Validation epoch 43: Loss = 1.8219902477547771, Accuracy = 0.7704917788505554
# Training epoch 44: Loss = 0.050439074635505676, Accuracy = 0.9904986619949341
# Validation epoch 44: Loss = 1.5347002653679886, Accuracy = 0.6721311211585999
# Training epoch 45: Loss = 0.026919476687908173, Accuracy = 0.9969135522842407
# Validation epoch 45: Loss = 1.3296511262716328, Accuracy = 0.7540983557701111
# Training epoch 46: Loss = 0.0199930090457201, Accuracy = 0.9994856119155884
# Validation epoch 46: Loss = 0.8522627342370201, Accuracy = 0.8360655903816223
# Training epoch 47: Loss = 0.018994292244315147, Accuracy = 0.9987291097640991
# Validation epoch 47: Loss = 0.857760989275135, Accuracy = 0.7704917788505554
# Training epoch 48: Loss = 0.018249107524752617, Accuracy = 0.9992284178733826
# Validation epoch 48: Loss = 1.1914254890480003, Accuracy = 0.7540983557701111
# Training epoch 49: Loss = 0.016739048063755035, Accuracy = 0.9995007514953613
# Validation epoch 49: Loss = 1.3428249270273525, Accuracy = 0.7377049326896667

# %%
m1= model_cnn.fit_generator(
            test_generator,
            epochs=100,
            validation_data=validation_generator,
            class_weight = 'model.h5',
#             callbacks= Callbacks,
            verbose=False)

# %%
model_cnn.evaluate
