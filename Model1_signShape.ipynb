# %%
import tensorflow as tf
AUTOTUNE = tf.data.experimental.AUTOTUNE

import IPython.display as display
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os

import pandas as pd

tf.__version__
# Out:
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow_core/__init__.py:1467: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
# '1.15.2'

# %%
import zipfile
with zipfile.ZipFile('./augmented_data.zip', 'r') as zip_ref:
    zip_ref.extractall('./')

# %%
from PIL import Image
import pandas as pd
import glob
image_list = []
for filepath in glob.glob('./augmented_data/*/*.png', recursive=True): #assuming gif
    filename = filepath.split("/")[-1]
    label = filepath.split("/")[-2]
#     print(filepath, filename, label)
    image_list.append((filepath, label))
#     print(filepath, label)
    
# Create a data frame
data = pd.DataFrame(data=image_list, columns=['image_path', 'label'])

# %%
r_inx = np.random.choice(2000, 4)
rand_data = data.loc[r_inx,'image_path']

plt.figure(figsize=(16,4))
for i, image_path in enumerate(rand_data):
    im = np.asarray(Image.open(image_path))
    plt.subplot(1,4,i+1)
    plt.imshow(im,cmap='gray')
    plt.axis('off')
    
plt.show()

# %%
data
# Out:
#                                          image_path     label
# 0              ./augmented_data/hex/hex1_0_5459.png       hex
# 1              ./augmented_data/hex/hex6_0_6304.png       hex
# 2              ./augmented_data/hex/hex2_0_8721.png       hex
# 3              ./augmented_data/hex/hex6_0_1245.png       hex
# 4              ./augmented_data/hex/00554_00000.png       hex
# 5              ./augmented_data/hex/hex6_0_5781.png       hex
# 6              ./augmented_data/hex/hex5_0_3667.png       hex
# 7              ./augmented_data/hex/hex3_0_9286.png       hex
# 8              ./augmented_data/hex/hex4_0_3368.png       hex
# 9              ./augmented_data/hex/00685_00000.png       hex
# 10             ./augmented_data/hex/hex6_0_1010.png       hex
# 11             ./augmented_data/hex/hex4_0_1266.png       hex
# 12             ./augmented_data/hex/hex2_0_3005.png       hex
# 13             ./augmented_data/hex/hex4_0_4855.png       hex
# 14             ./augmented_data/hex/hex5_0_2394.png       hex
# 15              ./augmented_data/hex/hex6_0_458.png       hex
# 16              ./augmented_data/hex/hex1_0_816.png       hex
# 17             ./augmented_data/hex/hex4_0_7165.png       hex
# 18             ./augmented_data/hex/hex6_0_8543.png       hex
# 19             ./augmented_data/hex/hex3_0_8185.png       hex
# 20             ./augmented_data/hex/hex1_0_5313.png       hex
# 21             ./augmented_data/hex/hex4_0_4634.png       hex
# 22             ./augmented_data/hex/hex2_0_3232.png       hex
# 23             ./augmented_data/hex/hex4_0_9276.png       hex
# 24              ./augmented_data/hex/hex1_0_282.png       hex
# 25             ./augmented_data/hex/hex4_0_8231.png       hex
# 26             ./augmented_data/hex/hex5_0_4322.png       hex
# 27             ./augmented_data/hex/hex1_0_3353.png       hex
# 28             ./augmented_data/hex/hex1_0_4746.png       hex
# 29             ./augmented_data/hex/hex5_0_3896.png       hex
# ...                                             ...       ...
# 4823      ./augmented_data/triangle/00877_00000.png  triangle
# 4824      ./augmented_data/triangle/00307_00002.png  triangle
# 4825      ./augmented_data/triangle/01720_00002.png  triangle
# 4826      ./augmented_data/triangle/01423_00001.png  triangle
# 4827      ./augmented_data/triangle/00257_00002.png  triangle
# 4828      ./augmented_data/triangle/01531_00002.png  triangle
# 4829      ./augmented_data/triangle/00240_00002.png  triangle
# 4830      ./augmented_data/triangle/00058_00000.png  triangle
# 4831      ./augmented_data/triangle/00736_00001.png  triangle
# 4832      ./augmented_data/triangle/00023_00000.png  triangle
# 4833  ./augmented_data/triangle/triangle1_0_511.png  triangle
# 4834      ./augmented_data/triangle/01028_00000.png  triangle
# 4835      ./augmented_data/triangle/00689_00003.png  triangle
# 4836      ./augmented_data/triangle/00002_00002.png  triangle
# 4837      ./augmented_data/triangle/00235_00001.png  triangle
# 4838      ./augmented_data/triangle/00253_00000.png  triangle
# 4839      ./augmented_data/triangle/00057_00001.png  triangle
# 4840      ./augmented_data/triangle/00729_00002.png  triangle
# 4841      ./augmented_data/triangle/01203_00002.png  triangle
# 4842      ./augmented_data/triangle/01349_00000.png  triangle
# 4843      ./augmented_data/triangle/00017_00001.png  triangle
# 4844      ./augmented_data/triangle/00614_00002.png  triangle
# 4845      ./augmented_data/triangle/01720_00001.png  triangle
# 4846      ./augmented_data/triangle/00980_00000.png  triangle
# 4847      ./augmented_data/triangle/00920_00001.png  triangle
# 4848      ./augmented_data/triangle/01377_00001.png  triangle
# 4849      ./augmented_data/triangle/00675_00002.png  triangle
# 4850      ./augmented_data/triangle/00614_00000.png  triangle
# 4851      ./augmented_data/triangle/01433_00002.png  triangle
# 4852      ./augmented_data/triangle/01106_00000.png  triangle
#
# [4853 rows x 2 columns]

# %%
data.sample(frac=1)
# Out:
#                                             image_path     label
# 3301           ./augmented_data/square/01690_00000.png    square
# 1556            ./augmented_data/round/01646_00002.png     round
# 3816           ./augmented_data/square/01410_00002.png    square
# 3119           ./augmented_data/square/00593_00002.png    square
# 598               ./augmented_data/hex/hex6_0_1773.png       hex
# 3359           ./augmented_data/square/00140_00002.png    square
# 897               ./augmented_data/hex/hex3_0_6200.png       hex
# 3909         ./augmented_data/triangle/00235_00002.png  triangle
# 3769         ./augmented_data/square/square1_0_464.png    square
# 3388        ./augmented_data/square/square4_0_4613.png    square
# 3618           ./augmented_data/square/01362_00001.png    square
# 1829  ./augmented_data/diamond/aug_diamond1_0_1889.png   diamond
# 828               ./augmented_data/hex/hex1_0_3269.png       hex
# 4655         ./augmented_data/triangle/01584_00002.png  triangle
# 603               ./augmented_data/hex/hex2_0_3931.png       hex
# 2695   ./augmented_data/diamond/aug_diamond_0_1308.png   diamond
# 1458            ./augmented_data/round/01230_00002.png     round
# 2040  ./augmented_data/diamond/aug_diamond5_0_5524.png   diamond
# 3873         ./augmented_data/triangle/00876_00002.png  triangle
# 3727           ./augmented_data/square/00788_00000.png    square
# 1667            ./augmented_data/round/01149_00000.png     round
# 75                ./augmented_data/hex/hex5_0_7900.png       hex
# 2708  ./augmented_data/diamond/aug_diamond1_0_9314.png   diamond
# 3511           ./augmented_data/square/01472_00001.png    square
# 2053  ./augmented_data/diamond/aug_diamond2_0_4187.png   diamond
# 4576         ./augmented_data/triangle/00252_00001.png  triangle
# 1485            ./augmented_data/round/00975_00003.png     round
# 4197         ./augmented_data/triangle/01377_00000.png  triangle
# 4000         ./augmented_data/triangle/01207_00000.png  triangle
# 2112  ./augmented_data/diamond/aug_diamond5_0_3706.png   diamond
# ...                                                ...       ...
# 2326          ./augmented_data/diamond/01254_00000.png   diamond
# 2751   ./augmented_data/diamond/aug_diamond1_0_455.png   diamond
# 2801  ./augmented_data/diamond/aug_diamond3_0_5943.png   diamond
# 1815            ./augmented_data/round/01066_00002.png     round
# 947             ./augmented_data/round/00402_00000.png     round
# 606               ./augmented_data/hex/hex6_0_8409.png       hex
# 997             ./augmented_data/round/01112_00002.png     round
# 4430         ./augmented_data/triangle/00729_00000.png  triangle
# 4716         ./augmented_data/triangle/00051_00000.png  triangle
# 4653         ./augmented_data/triangle/00331_00002.png  triangle
# 3184        ./augmented_data/square/square3_0_6057.png    square
# 2056  ./augmented_data/diamond/aug_diamond5_0_4121.png   diamond
# 254                ./augmented_data/hex/hex6_0_238.png       hex
# 817               ./augmented_data/hex/hex6_0_1694.png       hex
# 1662            ./augmented_data/round/01312_00001.png     round
# 895               ./augmented_data/hex/hex1_0_5404.png       hex
# 3453           ./augmented_data/square/00827_00002.png    square
# 3385        ./augmented_data/square/square3_0_4094.png    square
# 571               ./augmented_data/hex/hex1_0_6716.png       hex
# 2448  ./augmented_data/diamond/aug_diamond1_0_1525.png   diamond
# 3866         ./augmented_data/triangle/00148_00001.png  triangle
# 1912  ./augmented_data/diamond/aug_diamond2_0_8323.png   diamond
# 3740        ./augmented_data/square/square1_0_4005.png    square
# 553               ./augmented_data/hex/hex3_0_8760.png       hex
# 3309           ./augmented_data/square/01792_00002.png    square
# 1528            ./augmented_data/round/01181_00001.png     round
# 1647            ./augmented_data/round/00565_00001.png     round
# 4320         ./augmented_data/triangle/01574_00002.png  triangle
# 3506           ./augmented_data/square/00485_00001.png    square
# 1467            ./augmented_data/round/01620_00001.png     round
#
# [4853 rows x 2 columns]

# %%
# Generate two data frames for training and validation
first_split = data.sample(frac=0.8).reset_index()
# print(first_split)
second_split= data.drop(first_split.index)
# print(second_split)

print('Train size: {}, Test size: {}'.format(first_split.shape[0], second_split.shape[0] ) )
N_train_images = first_split.shape[0]
N_val_images = second_split.shape[0]
# Out:
# Train size: 3882, Test size: 971

# %%
from sklearn.model_selection import train_test_split

train_df, validation_df = train_test_split(data, test_size=0.2)

# %%
# isinstance(train_df, pd.DataFrame)

# %%
batch_size = 16

# %%
def calculate_losses(model_in, data_generator_in, N_images, batch_size_):
    loss_hold = []
    acc_hold = []
    batches = 0
    
    # iterate over each batch
    for x,y in data_generator_in:
        loss, acc = model_in.evaluate(x, y, verbose=0)
        loss_hold.append(loss)
        acc_hold.append(acc)
        batches += 1
        if batches >= N_images / batch_size_:
            # we need to break the loop by hand because
            # the generator loops indefinitely
            break
            
    return np.mean(loss_hold), np.mean(acc_hold)

# %%
def train_model(model_, train_generator_in, validation_generator_in, num_epoch=50, verbose=False):
    res = []
    for e in range(num_epoch):
        # print('Epoch', e)
        batches = 0

        loss_ = []
        acc_ = []

         # iterate over each batch
        for x,y in train_generator_in:
            loss, acc = model_.train_on_batch(x, y) # Update weights and return train loss, acc per batch
            loss_.append(loss)
            acc_.append(acc)
            batches += 1
            if batches >= N_train_images / batch_size:
                # we need to break the loop by hand because
                # the generator loops indefinitely
                break
        loss_ = np.mean(loss_)
        acc_ = np.mean(acc_)

        loss, acc = calculate_losses(model_, validation_generator_in, N_val_images, batch_size)
        if verbose:
            print("Training epoch {}: Loss = {}, Accuracy = {}".format(e, loss_, acc_))
            print("Testing epoch {}: Loss = {}, Accuracy = {}".format(e, loss, acc))

        res.append((e, loss_, acc_, loss, acc))
    return np.asarray(res)

# %%
def plot_results(res):
    plt.figure(figsize=(12,4))
    plt.subplot(1,2,1)
    plt.plot(res[:,0], res[:,1], 'r-')
    plt.plot(res[:,0], res[:,3], 'b-')
    plt.legend(['Train', 'Testing'])
    plt.xlabel('epoch')
    plt.ylabel('Loss')
    plt.ylim([0, np.max([5., np.max(res[:,1]), np.max(res[:,3])])])

    plt.subplot(1,2,2)
    plt.plot(res[:,0], res[:,2], 'r-')
    plt.plot(res[:,0], res[:,4], 'b-')
    plt.legend(['Train', 'Testing'])
    plt.xlabel('epoch')
    plt.ylabel('Accuracy')
    plt.ylim([0, np.max([1., np.max(res[:,2]), np.max(res[:,4])])])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')
val_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

batch_size = 16

train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_df,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size,
        class_mode='categorical')

validation_generator = val_datagen.flow_from_dataframe(
        dataframe=validation_df,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size,
        class_mode='categorical')
# Out:
# Found 3882 validated image filenames belonging to 5 classes.
# Found 971 validated image filenames belonging to 5 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Lambda, Input
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.metrics import categorical_accuracy
from tensorflow.keras import regularizers, optimizers

model_cnn = Sequential()

# input
model_cnn.add(Input(shape=(28, 28, 3)))
model_cnn.add(Lambda(lambda x: tf.expand_dims(x[:,:,:,0], -1, name=None))) 


# Conv Layer 1
model_cnn.add(Conv2D(32, (3, 3),kernel_regularizer=regularizers.l2(0.001)))
model_cnn.add(Activation('relu'))
model_cnn.add(MaxPooling2D(pool_size=(2, 2)))

# Conv Layer 2 (no pooling)
model_cnn.add(Conv2D(32, (3, 3),kernel_regularizer=regularizers.l2(0.001)))
model_cnn.add(Activation('relu'))

# Conv Layer 3
model_cnn.add(Conv2D(64, (3, 3)))
model_cnn.add(Activation('relu'))
model_cnn.add(MaxPooling2D(pool_size=(2, 2)))

# MLP
model_cnn.add(Flatten())
model_cnn.add(Dense(64))
model_cnn.add(Activation('relu'))
model_cnn.add(Dropout(0.5))
model_cnn.add(Dense(5))
model_cnn.add(Activation('softmax'))

sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model_cnn.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=[categorical_accuracy])


model_cnn.save_weights('model.h5')

model_cnn.summary()
# Out:
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:OMP_NUM_THREADS is no longer used by the default Keras config. To configure the number of threads, use tf.config.threading APIs.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda (Lambda)              (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# activation (Activation)      (None, 26, 26, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 11, 11, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 64)          18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 9, 9, 64)          0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                65600
# _________________________________________________________________
# activation_3 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 325
# _________________________________________________________________
# activation_4 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 93,989
# Trainable params: 93,989
# Non-trainable params: 0
# _________________________________________________________________

# %%
res = train_model(model_cnn, train_generator, validation_generator, num_epoch=50, verbose=1)
plot_results(res)
# Out:
# Training epoch 0: Loss = 1.3668609857559204, Accuracy = 0.4293724298477173
# Validation epoch 0: Loss = 0.7917339919043369, Accuracy = 0.7593144178390503
# Training epoch 1: Loss = 0.5856615304946899, Accuracy = 0.8147328495979309
# Validation epoch 1: Loss = 0.26428838391773035, Accuracy = 0.9273472428321838
# Training epoch 2: Loss = 0.2942139506340027, Accuracy = 0.9175963997840881
# Validation epoch 2: Loss = 0.19920348498176355, Accuracy = 0.9446721076965332
# Training epoch 3: Loss = 0.20657508075237274, Accuracy = 0.9480986595153809
# Validation epoch 3: Loss = 0.12910464522047121, Accuracy = 0.9769933223724365
# Training epoch 4: Loss = 0.15190276503562927, Accuracy = 0.9661046266555786
# Validation epoch 4: Loss = 0.11565920588422994, Accuracy = 0.9846311211585999
# Training epoch 5: Loss = 0.13827922940254211, Accuracy = 0.9714506268501282
# Validation epoch 5: Loss = 0.13056184241517646, Accuracy = 0.9728949666023254
# Training epoch 6: Loss = 0.121387779712677, Accuracy = 0.976804256439209
# Validation epoch 6: Loss = 0.08813344516226503, Accuracy = 0.9887295365333557
# Training epoch 7: Loss = 0.12640005350112915, Accuracy = 0.9742798209190369
# Validation epoch 7: Loss = 0.108705820912709, Accuracy = 0.9831408262252808
# Training epoch 8: Loss = 0.10012409090995789, Accuracy = 0.9826151132583618
# Validation epoch 8: Loss = 0.0854679536624033, Accuracy = 0.9918032884597778
# Training epoch 9: Loss = 0.06805635988712311, Accuracy = 0.9925411343574524
# Validation epoch 9: Loss = 0.07143890595094102, Accuracy = 0.9897540807723999
# Training epoch 10: Loss = 0.0968594178557396, Accuracy = 0.9808146953582764
# Validation epoch 10: Loss = 0.08655877087692745, Accuracy = 0.9923621416091919
# Training epoch 11: Loss = 0.07260225713253021, Accuracy = 0.9903311133384705
# Validation epoch 11: Loss = 0.07653791304738795, Accuracy = 0.9933867454528809
# Training epoch 12: Loss = 0.0646648034453392, Accuracy = 0.9936747550964355
# Validation epoch 12: Loss = 0.07394649057847555, Accuracy = 0.9907786846160889
# Training epoch 13: Loss = 0.057549018412828445, Accuracy = 0.9952179789543152
# Validation epoch 13: Loss = 0.06646625190729001, Accuracy = 0.9918032884597778
# Training epoch 14: Loss = 0.06772073358297348, Accuracy = 0.9895575642585754
# Validation epoch 14: Loss = 0.08289384799169712, Accuracy = 0.9877049326896667
# Training epoch 15: Loss = 0.06895876675844193, Accuracy = 0.9904835224151611
# Validation epoch 15: Loss = 0.06709496353249081, Accuracy = 0.9928278923034668
# Training epoch 16: Loss = 0.05082394927740097, Accuracy = 0.9961419701576233
# Validation epoch 16: Loss = 0.0688043833389634, Accuracy = 0.993852436542511
# Training epoch 17: Loss = 0.05172315612435341, Accuracy = 0.9948559403419495
# Validation epoch 17: Loss = 0.09369244457024042, Accuracy = 0.9897540807723999
# Training epoch 18: Loss = 0.05612368509173393, Accuracy = 0.9925411343574524
# Validation epoch 18: Loss = 0.1245217063143605, Accuracy = 0.9836065769195557
# Training epoch 19: Loss = 0.054397355765104294, Accuracy = 0.9934155941009521
# Validation epoch 19: Loss = 0.07463353035635635, Accuracy = 0.9897540807723999
# Training epoch 20: Loss = 0.04736516624689102, Accuracy = 0.9938271641731262
# Validation epoch 20: Loss = 0.07089797978396298, Accuracy = 0.9918032884597778
# Training epoch 21: Loss = 0.046434566378593445, Accuracy = 0.9956275820732117
# Validation epoch 21: Loss = 0.07300680610122251, Accuracy = 0.9897540807723999
# Training epoch 22: Loss = 0.04377543926239014, Accuracy = 0.9969135522842407
# Validation epoch 22: Loss = 0.09166779149262631, Accuracy = 0.9784836173057556
# Training epoch 23: Loss = 0.04516344144940376, Accuracy = 0.995475172996521
# Validation epoch 23: Loss = 0.05979142301395291, Accuracy = 0.993852436542511
# Training epoch 24: Loss = 0.0338255874812603, Accuracy = 0.9981995820999146
# Validation epoch 24: Loss = 0.06875972587187759, Accuracy = 0.9918032884597778
# Training epoch 25: Loss = 0.03737618774175644, Accuracy = 0.9963991641998291
# Validation epoch 25: Loss = 0.06167684913780846, Accuracy = 0.9928278923034668
# Training epoch 26: Loss = 0.03354518488049507, Accuracy = 0.9966563582420349
# Validation epoch 26: Loss = 0.06324430301663328, Accuracy = 0.9907786846160889
# Training epoch 27: Loss = 0.02923453040421009, Accuracy = 0.998971164226532
# Validation epoch 27: Loss = 0.06607001851938787, Accuracy = 0.9918032884597778
# Training epoch 28: Loss = 0.03274887800216675, Accuracy = 0.9956275820732117
# Validation epoch 28: Loss = 0.05452239204992036, Accuracy = 0.993852436542511
# Training epoch 29: Loss = 0.02881343849003315, Accuracy = 0.9984567761421204
# Validation epoch 29: Loss = 0.05848337905328782, Accuracy = 0.9918032884597778
# Training epoch 30: Loss = 0.03548330068588257, Accuracy = 0.9963991641998291
# Validation epoch 30: Loss = 0.06929262382451629, Accuracy = 0.9897540807723999
# Training epoch 31: Loss = 0.041488710790872574, Accuracy = 0.9933127760887146
# Validation epoch 31: Loss = 0.06649996550967459, Accuracy = 0.9907786846160889
# Training epoch 32: Loss = 0.026010755449533463, Accuracy = 0.9994856119155884
# Validation epoch 32: Loss = 0.055436790691780265, Accuracy = 0.9928278923034668
# Training epoch 33: Loss = 0.03674265369772911, Accuracy = 0.9951131939888
# Validation epoch 33: Loss = 0.049593642262406035, Accuracy = 0.9918032884597778
# Training epoch 34: Loss = 0.029365288093686104, Accuracy = 0.9969135522842407
# Validation epoch 34: Loss = 0.0565401659820412, Accuracy = 0.9897540807723999
# Training epoch 35: Loss = 0.023941485211253166, Accuracy = 0.9994856119155884
# Validation epoch 35: Loss = 0.04926744582833814, Accuracy = 0.9928278923034668
# Training epoch 36: Loss = 0.04191109910607338, Accuracy = 0.9933127760887146
# Validation epoch 36: Loss = 0.113763459484841, Accuracy = 0.9815573692321777
# Training epoch 37: Loss = 0.0366058349609375, Accuracy = 0.9941891431808472
# Validation epoch 37: Loss = 0.05958355092977891, Accuracy = 0.9948770403862
# Training epoch 38: Loss = 0.03855760768055916, Accuracy = 0.9938271641731262
# Validation epoch 38: Loss = 0.047927792016111435, Accuracy = 0.9928278923034668
# Training epoch 39: Loss = 0.036540742963552475, Accuracy = 0.9963991641998291
# Validation epoch 39: Loss = 0.05022160882954715, Accuracy = 0.9928278923034668
# Training epoch 40: Loss = 0.0327303372323513, Accuracy = 0.9958847761154175
# Validation epoch 40: Loss = 0.05089152750910306, Accuracy = 0.9928278923034668
# Training epoch 41: Loss = 0.03463657200336456, Accuracy = 0.9948559403419495
# Validation epoch 41: Loss = 0.060476631414694865, Accuracy = 0.9887295365333557
# Training epoch 42: Loss = 0.026378966867923737, Accuracy = 0.9979423880577087
# Validation epoch 42: Loss = 0.05369170287959888, Accuracy = 0.9907786846160889
# Training epoch 43: Loss = 0.0321773961186409, Accuracy = 0.9961419701576233
# Validation epoch 43: Loss = 0.059315497574747585, Accuracy = 0.9907786846160889
# Training epoch 44: Loss = 0.029718101024627686, Accuracy = 0.9967592358589172
# Validation epoch 44: Loss = 0.06541905518560136, Accuracy = 0.9918032884597778
# Training epoch 45: Loss = 0.02499728463590145, Accuracy = 0.9979423880577087
# Validation epoch 45: Loss = 0.04073634255127829, Accuracy = 0.9944113492965698
# Training epoch 46: Loss = 0.025202570483088493, Accuracy = 0.9973785281181335
# Validation epoch 46: Loss = 0.05635716622603721, Accuracy = 0.9928278923034668
# Training epoch 47: Loss = 0.02324100024998188, Accuracy = 0.9981995820999146
# Validation epoch 47: Loss = 0.04212419416938649, Accuracy = 0.993852436542511
# Training epoch 48: Loss = 0.021364329382777214, Accuracy = 0.998971164226532
# Validation epoch 48: Loss = 0.04154771697692207, Accuracy = 0.9918032884597778
# Training epoch 49: Loss = 0.021951133385300636, Accuracy = 0.9979423880577087
# Validation epoch 49: Loss = 0.059967695231564706, Accuracy = 0.9913375973701477

# %%
test_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

batch_size_t = 1

# Here the validation is used for testing and this should be changes to a separate test set.
test_generator = train_datagen.flow_from_dataframe(
        dataframe=validation_df,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size_t,
        class_mode='categorical')
# Out:
# Found 971 validated image filenames belonging to 5 classes.

# %%
d = {'diamond':0, 'hex':1, 'round':2, 'square':3, 'triangle':4}
data['labels_num'] = data['label'].map(d, na_action='ignore')

# %%
d_inv = {v: k for k, v in d.items()}
plt.figure(figsize=(16,4))
batches = 0
for x,y in test_generator:
        batches = batches + 1
        y_hat = model_cnn.predict(x, verbose=0)
        x = np.squeeze(x)
        if batches < 5:
            plt.subplot(1,5,batches)
            plt.imshow(x)
            plt.title("GT-{}, Pred-{}".format(d_inv[np.argmax(y[0])], d_inv[np.argmax(y_hat[0])] ))
            
        else:
            break
        
        plt.axis('off')

# %%
from PIL import Image
import pandas as pd
import glob
image_list = []
i = 0
for filepath in glob.glob('./labeled_test_data/*/*.png', recursive=True): #assuming gif
    newsize = (28,28)
    img = Image.open(filepath).convert('L').resize(newsize)
    path = ('./processed_test_images/'+str(i)+'.png')
    img.save(path, 'png')
    filename = path
    label = filepath.split("/")[-2]
#     print(filepath, filename, label)
    image_list.append((path, label))
    i = i + 1
    
# Create a data frame
german_test_data = pd.DataFrame(data=image_list, columns=['image_path', 'label'])

# %%
german_test_data
# Out:
#                             image_path   label
# 0        ./processed_test_images/0.png    TRSD
# 1        ./processed_test_images/1.png    TRSD
# 2        ./processed_test_images/2.png    TRSD
# 3        ./processed_test_images/3.png    TRSD
# 4        ./processed_test_images/4.png    TRSD
# 5        ./processed_test_images/5.png    TRSD
# 6        ./processed_test_images/6.png    TRSD
# 7        ./processed_test_images/7.png    TRSD
# 8        ./processed_test_images/8.png    TRSD
# 9        ./processed_test_images/9.png    TRSD
# 10      ./processed_test_images/10.png    TRSD
# 11      ./processed_test_images/11.png    TRSD
# 12      ./processed_test_images/12.png    TRSD
# 13      ./processed_test_images/13.png    TRSD
# 14      ./processed_test_images/14.png    TRSD
# 15      ./processed_test_images/15.png    TRSD
# 16      ./processed_test_images/16.png    TRSD
# 17      ./processed_test_images/17.png    TRSD
# 18      ./processed_test_images/18.png    TRSD
# 19      ./processed_test_images/19.png    TRSD
# 20      ./processed_test_images/20.png    TRSD
# 21      ./processed_test_images/21.png    TRSD
# 22      ./processed_test_images/22.png    TRSD
# 23      ./processed_test_images/23.png    TRSD
# 24      ./processed_test_images/24.png    TRSD
# 25      ./processed_test_images/25.png    TRSD
# 26      ./processed_test_images/26.png    TRSD
# 27      ./processed_test_images/27.png    TRSD
# 28      ./processed_test_images/28.png    TRSD
# 29      ./processed_test_images/29.png    TRSD
# ...                                ...     ...
# 1982  ./processed_test_images/1982.png    TRSD
# 1983  ./processed_test_images/1983.png    TRSD
# 1984  ./processed_test_images/1984.png    TRSD
# 1985  ./processed_test_images/1985.png    TRSD
# 1986  ./processed_test_images/1986.png    TRSD
# 1987  ./processed_test_images/1987.png    TRSD
# 1988  ./processed_test_images/1988.png    TRSD
# 1989  ./processed_test_images/1989.png    TRSD
# 1990  ./processed_test_images/1990.png    TRSD
# 1991  ./processed_test_images/1991.png    TRSD
# 1992  ./processed_test_images/1992.png    TRSD
# 1993  ./processed_test_images/1993.png    TRSD
# 1994  ./processed_test_images/1994.png  square
# 1995  ./processed_test_images/1995.png  square
# 1996  ./processed_test_images/1996.png  square
# 1997  ./processed_test_images/1997.png  square
# 1998  ./processed_test_images/1998.png  square
# 1999  ./processed_test_images/1999.png  square
# 2000  ./processed_test_images/2000.png  square
# 2001  ./processed_test_images/2001.png  square
# 2002  ./processed_test_images/2002.png  square
# 2003  ./processed_test_images/2003.png  square
# 2004  ./processed_test_images/2004.png  square
# 2005  ./processed_test_images/2005.png  square
# 2006  ./processed_test_images/2006.png  square
# 2007  ./processed_test_images/2007.png  square
# 2008  ./processed_test_images/2008.png  square
# 2009  ./processed_test_images/2009.png  square
# 2010  ./processed_test_images/2010.png  square
# 2011  ./processed_test_images/2011.png  square
#
# [2012 rows x 2 columns]

# %%
test_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

batch_size_t = 1

# Here the validation is used for testing and this should be changes to a separate test set.
test_generator = train_datagen.flow_from_dataframe(
        dataframe=german_test_data,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size_t,
        class_mode='categorical')
# Out:
# Found 2012 validated image filenames belonging to 2 classes.

# %%
d_inv = {v: k for k, v in d.items()}
plt.figure(figsize=(16,4))
batches = 0
for x,y in test_generator:
        batches = batches + 1
        y_hat = model_cnn.predict(x, verbose=0)
        x = np.squeeze(x)
        if batches < 5:
            plt.subplot(1,5,batches)
            plt.imshow(x)
            plt.title("GT-{}, Pred-{}".format(d_inv[np.argmax(y[0])], d_inv[np.argmax(y_hat[0])] ))
            
        else:
            break
        
        plt.axis('off')

# %%
res = train_model(model_cnn, train_generator, test_generator, num_epoch=50, verbose=1)
plot_results(res)

# %%
from PIL import Image
import pandas as pd
import glob
image_list = []
i = 0
for filepath in glob.glob('./chinese_traffic_sign/*/*.png', recursive=True): #assuming gif
    newsize = (28,28)
    img = Image.open(filepath).convert('L').resize(newsize)
    path = ('./chinese_processed_test_images/'+str(i)+'.png')
    img.save(path, 'png')
    filename = path
    label = filepath.split("/")[-2]
#     print(filepath, filename, label)
    image_list.append((filename, label))
    i = i + 1
    
# Create a data frame
chinese_test_data = pd.DataFrame(data=image_list, columns=['image_path', 'label'])

# %%
test_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

batch_size_t = 1

# Here the validation is used for testing and this should be changes to a separate test set.
test_generator = train_datagen.flow_from_dataframe(
        dataframe=chinese_test_data,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size_t,
        class_mode='categorical')
# Out:
# Found 102 validated image filenames belonging to 5 classes.

# %%
d = {'diamond':0, 'hex':1, 'round':2, 'square':3, 'triangle':4}
data['labels_num'] = data['label'].map(d, na_action='ignore')

# %%
d_inv = {v: k for k, v in d.items()}
plt.figure(figsize=(16,4))
batches = 0
for x,y in test_generator:
        batches = batches + 1
        y_hat = model_cnn.predict(x, verbose=0)
        x = np.squeeze(x)
        if batches < 5:
            plt.subplot(1,5,batches)
            plt.imshow(x)
            plt.title("GT-{}, Pred-{}".format(d_inv[np.argmax(y[0])], d_inv[np.argmax(y_hat[0])] ))
            
        else:
            break
        
        plt.axis('off')

# %%
res = train_model(model_cnn, train_generator, test_generator, num_epoch=50, verbose=1)
plot_results(res)
# Out:
# Training epoch 0: Loss = 0.01763291098177433, Accuracy = 0.9992284178733826
# Testing epoch 0: Loss = 2.429347165524349, Accuracy = 0.7213114500045776
# Training epoch 1: Loss = 0.016462495550513268, Accuracy = 0.9994856119155884
# Testing epoch 1: Loss = 2.2989025824840685, Accuracy = 0.7213114500045776
# Training epoch 2: Loss = 0.023955650627613068, Accuracy = 0.996414303779602
# Testing epoch 2: Loss = 1.9719062453196918, Accuracy = 0.7213114500045776
# Training epoch 3: Loss = 0.016351602971553802, Accuracy = 0.9994856119155884
# Testing epoch 3: Loss = 2.7286649396429294, Accuracy = 0.6557376980781555
# Training epoch 4: Loss = 0.05008649453520775, Accuracy = 0.9879115223884583
# Testing epoch 4: Loss = 2.540109038597248, Accuracy = 0.6065573692321777
# Training epoch 5: Loss = 0.041361160576343536, Accuracy = 0.9904986619949341
# Testing epoch 5: Loss = 1.9856919954973655, Accuracy = 0.7213114500045776
# Training epoch 6: Loss = 0.04049127176403999, Accuracy = 0.9920418858528137
# Testing epoch 6: Loss = 1.0567331209961996, Accuracy = 0.8196721076965332
# Training epoch 7: Loss = 0.027079856023192406, Accuracy = 0.9974279999732971
# Testing epoch 7: Loss = 1.5454692291248529, Accuracy = 0.7704917788505554
# Training epoch 8: Loss = 0.023305248469114304, Accuracy = 0.9992284178733826
# Testing epoch 8: Loss = 1.9695523199854328, Accuracy = 0.7704917788505554
# Training epoch 9: Loss = 0.028909383341670036, Accuracy = 0.9971708059310913
# Testing epoch 9: Loss = 1.6157064264731817, Accuracy = 0.8360655903816223
# Training epoch 10: Loss = 0.021222494542598724, Accuracy = 0.9985596537590027
# Testing epoch 10: Loss = 1.6043182196187191, Accuracy = 0.7213114500045776
# Training epoch 11: Loss = 0.018781336024403572, Accuracy = 1.0
# Testing epoch 11: Loss = 1.497008599982154, Accuracy = 0.8196721076965332
# Training epoch 12: Loss = 0.020487675443291664, Accuracy = 0.9974431395530701
# Testing epoch 12: Loss = 0.9874497132650653, Accuracy = 0.8524590134620667
# Training epoch 13: Loss = 0.017645690590143204, Accuracy = 0.9994856119155884
# Testing epoch 13: Loss = 3.23067833869489, Accuracy = 0.6065573692321777
# Training epoch 14: Loss = 0.020307697355747223, Accuracy = 0.9982147216796875
# Testing epoch 14: Loss = 1.4098372989807462, Accuracy = 0.7868852615356445
# Training epoch 15: Loss = 0.020228736102581024, Accuracy = 0.9976851940155029
# Testing epoch 15: Loss = 1.7808456301963964, Accuracy = 0.7049180269241333
# Training epoch 16: Loss = 0.024257801473140717, Accuracy = 0.9971708059310913
# Testing epoch 16: Loss = 3.000745256278725, Accuracy = 0.7049180269241333
# Training epoch 17: Loss = 0.020176798105239868, Accuracy = 0.9984567761421204
# Testing epoch 17: Loss = 1.231035664524944, Accuracy = 0.7868852615356445
# Training epoch 18: Loss = 0.019612465053796768, Accuracy = 0.998971164226532
# Testing epoch 18: Loss = 1.7046388052556602, Accuracy = 0.6557376980781555
# Training epoch 19: Loss = 0.016255691647529602, Accuracy = 0.9995007514953613
# Testing epoch 19: Loss = 1.7443773379915806, Accuracy = 0.7213114500045776
# Training epoch 20: Loss = 0.015991775318980217, Accuracy = 0.9992284178733826
# Testing epoch 20: Loss = 2.08911014351322, Accuracy = 0.7540983557701111
# Training epoch 21: Loss = 0.01383986882865429, Accuracy = 0.9997428059577942
# Testing epoch 21: Loss = 1.4859581613821573, Accuracy = 0.8196721076965332
# Training epoch 22: Loss = 0.012310168705880642, Accuracy = 1.0
# Testing epoch 22: Loss = 1.7715022547598012, Accuracy = 0.7377049326896667
# Training epoch 23: Loss = 0.015865392982959747, Accuracy = 0.9981995820999146
# Testing epoch 23: Loss = 1.1654256488059143, Accuracy = 0.8360655903816223
# Training epoch 24: Loss = 0.012446144595742226, Accuracy = 0.9995007514953613
# Testing epoch 24: Loss = 1.3991609014662318, Accuracy = 0.8032786846160889
# Training epoch 25: Loss = 0.01385630201548338, Accuracy = 0.9992284178733826
# Testing epoch 25: Loss = 1.7885118039538626, Accuracy = 0.6721311211585999
# Training epoch 26: Loss = 0.013358233496546745, Accuracy = 0.9992435574531555
# Testing epoch 26: Loss = 0.6916694040333883, Accuracy = 0.9180327653884888
# Training epoch 27: Loss = 0.01136829238384962, Accuracy = 1.0
# Testing epoch 27: Loss = 1.6571735686729434, Accuracy = 0.7213114500045776
# Training epoch 28: Loss = 0.010718641802668571, Accuracy = 1.0
# Testing epoch 28: Loss = 1.6219132001679697, Accuracy = 0.7049180269241333
# Training epoch 29: Loss = 0.0399145744740963, Accuracy = 0.9894547462463379
# Testing epoch 29: Loss = 1.9352622644090263, Accuracy = 0.6065573692321777
# Training epoch 30: Loss = 0.04669492319226265, Accuracy = 0.9902263283729553
# Testing epoch 30: Loss = 2.212052576518694, Accuracy = 0.7540983557701111
# Training epoch 31: Loss = 0.031787242740392685, Accuracy = 0.9951131939888
# Testing epoch 31: Loss = 1.8741929258113024, Accuracy = 0.7704917788505554
# Training epoch 32: Loss = 0.024139828979969025, Accuracy = 0.9971858859062195
# Testing epoch 32: Loss = 1.4946159821797589, Accuracy = 0.7377049326896667
# Training epoch 33: Loss = 0.020532015711069107, Accuracy = 0.9982147216796875
# Testing epoch 33: Loss = 1.864142472412987, Accuracy = 0.7704917788505554
# Training epoch 34: Loss = 0.02196287177503109, Accuracy = 0.9984567761421204
# Testing epoch 34: Loss = 1.7424654158015476, Accuracy = 0.7868852615356445
# Training epoch 35: Loss = 0.01954195462167263, Accuracy = 0.9987291097640991
# Testing epoch 35: Loss = 2.5718287853218738, Accuracy = 0.7049180269241333
# Training epoch 36: Loss = 0.015648066997528076, Accuracy = 0.9997579455375671
# Testing epoch 36: Loss = 2.3564068364956583, Accuracy = 0.7377049326896667
# Training epoch 37: Loss = 0.01608533225953579, Accuracy = 0.9987139701843262
# Testing epoch 37: Loss = 1.8860150734268006, Accuracy = 0.7868852615356445
# Training epoch 38: Loss = 0.028164198622107506, Accuracy = 0.9948559403419495
# Testing epoch 38: Loss = 2.4710171365744023, Accuracy = 0.7213114500045776
# Training epoch 39: Loss = 0.01812579669058323, Accuracy = 0.9987291097640991
# Testing epoch 39: Loss = 1.417926092738988, Accuracy = 0.8360655903816223
# Training epoch 40: Loss = 0.015437641181051731, Accuracy = 0.9992435574531555
# Testing epoch 40: Loss = 2.986385601664298, Accuracy = 0.688524603843689
# Training epoch 41: Loss = 0.01592794433236122, Accuracy = 0.9989863038063049
# Testing epoch 41: Loss = 2.0477812195532636, Accuracy = 0.7868852615356445
# Training epoch 42: Loss = 0.02298981323838234, Accuracy = 0.9966563582420349
# Testing epoch 42: Loss = 1.7216447964310646, Accuracy = 0.7540983557701111
# Training epoch 43: Loss = 0.017461426556110382, Accuracy = 0.998971164226532
# Testing epoch 43: Loss = 2.405181111080847, Accuracy = 0.7540983557701111
# Training epoch 44: Loss = 0.016208620741963387, Accuracy = 0.998971164226532
# Testing epoch 44: Loss = 2.371609648796501, Accuracy = 0.7704917788505554
# Training epoch 45: Loss = 0.02133365161716938, Accuracy = 0.9969135522842407
# Testing epoch 45: Loss = 3.1696673597316027, Accuracy = 0.6393442749977112
# Training epoch 46: Loss = 0.01991720125079155, Accuracy = 0.9969286918640137
# Testing epoch 46: Loss = 1.8075497218514565, Accuracy = 0.7868852615356445
# Training epoch 47: Loss = 0.01628156378865242, Accuracy = 0.9984719157218933
# Testing epoch 47: Loss = 1.9798470883492807, Accuracy = 0.7868852615356445
# Training epoch 48: Loss = 0.013359260745346546, Accuracy = 0.9995007514953613
# Testing epoch 48: Loss = 1.6653505081127657, Accuracy = 0.7377049326896667
# Training epoch 49: Loss = 0.012716777622699738, Accuracy = 0.9997428059577942
# Testing epoch 49: Loss = 2.415449055049141, Accuracy = 0.7213114500045776
