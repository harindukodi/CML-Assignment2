# %%
import tensorflow as tf
AUTOTUNE = tf.data.experimental.AUTOTUNE

import IPython.display as display
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os
    
import pandas as pd

tf.__version__
# Out:
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow_core/__init__.py:1467: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
# '1.15.2'

# %%
import zipfile
with zipfile.ZipFile('./sign_type_data.zip', 'r') as zip_ref:
    zip_ref.extractall('./')

# %%
from PIL import Image
import pandas as pd
import glob
image_list = []
for filepath in glob.glob('./sign_type_data/*/*.png', recursive=True): #assuming gif
    filename = filepath.split("/")[-1]
    label = filepath.split("/")[-2]
#     print(filepath, filename, label)
    image_list.append((filepath, label))
#     print(filepath, label)
    
# Create a data frame
data = pd.DataFrame(data=image_list, columns=['image_path', 'label'])

# %%
r_inx = np.random.choice(2000, 4)
rand_data = data.loc[r_inx,'image_path']

plt.figure(figsize=(16,4))
for i, image_path in enumerate(rand_data):
    im = np.asarray(Image.open(image_path))
    plt.subplot(1,4,i+1)
    plt.imshow(im,cmap='gray')
    plt.axis('off')
    
plt.show()

# %%
data.sample(frac=1)
# Out:
#                                              image_path             label
# 780         ./sign_type_data/roundabout/00975_00003.png        roundabout
# 2487  ./sign_type_data/trafficdirective/01909_00000.png  trafficdirective
# 3093           ./sign_type_data/parking/00457_00000.png           parking
# 726         ./sign_type_data/roundabout/00807_00002.png        roundabout
# 2687              ./sign_type_data/stop/01920_00001.png              stop
# 719         ./sign_type_data/roundabout/00973_00000.png        roundabout
# 1106           ./sign_type_data/noentry/01168_00000.png           noentry
# 312          ./sign_type_data/noparking/00993_00002.png         noparking
# 187            ./sign_type_data/giveway/01749_00001.png           giveway
# 295          ./sign_type_data/noparking/01697_00001.png         noparking
# 3655        ./sign_type_data/rightofway/00060_00000.png        rightofway
# 1664           ./sign_type_data/warning/01016_00001.png           warning
# 2978           ./sign_type_data/parking/00803_00000.png           parking
# 239          ./sign_type_data/noparking/00452_00000.png         noparking
# 1862           ./sign_type_data/warning/01681_00002.png           warning
# 2677  ./sign_type_data/trafficdirective/01184_00000.png  trafficdirective
# 1526           ./sign_type_data/warning/00801_00000.png           warning
# 2582  ./sign_type_data/trafficdirective/00272_00002.png  trafficdirective
# 2288           ./sign_type_data/bicycle/01208_00000.png           bicycle
# 3307          ./sign_type_data/continue/01463_00001.png          continue
# 3023           ./sign_type_data/parking/00035_00002.png           parking
# 990            ./sign_type_data/noentry/01676_00001.png           noentry
# 2121           ./sign_type_data/warning/01893_00000.png           warning
# 597            ./sign_type_data/laneend/01624_00001.png           laneend
# 3500        ./sign_type_data/rightofway/01957_00002.png        rightofway
# 1914           ./sign_type_data/warning/01724_00002.png           warning
# 3265          ./sign_type_data/continue/01167_00002.png          continue
# 88             ./sign_type_data/giveway/01829_00000.png           giveway
# 3244          ./sign_type_data/continue/01056_00002.png          continue
# 349          ./sign_type_data/noparking/00787_00002.png         noparking
# ...                                                 ...               ...
# 2194           ./sign_type_data/warning/00614_00002.png           warning
# 1183           ./sign_type_data/noentry/01066_00002.png           noentry
# 2379           ./sign_type_data/bicycle/01963_00000.png           bicycle
# 1616           ./sign_type_data/warning/00262_00001.png           warning
# 573    ./sign_type_data/traveldirection/00370_00001.png   traveldirection
# 819            ./sign_type_data/noentry/01246_00001.png           noentry
# 81             ./sign_type_data/giveway/00980_00001.png           giveway
# 2628  ./sign_type_data/trafficdirective/01716_00001.png  trafficdirective
# 2331           ./sign_type_data/bicycle/00462_00001.png           bicycle
# 1057           ./sign_type_data/noentry/01057_00001.png           noentry
# 2217           ./sign_type_data/bicycle/00171_00001.png           bicycle
# 3639        ./sign_type_data/rightofway/00943_00000.png        rightofway
# 1033           ./sign_type_data/noentry/01221_00002.png           noentry
# 3369          ./sign_type_data/continue/01625_00002.png          continue
# 2026           ./sign_type_data/warning/00051_00001.png           warning
# 1111           ./sign_type_data/noentry/01696_00002.png           noentry
# 1698           ./sign_type_data/warning/00138_00002.png           warning
# 2173           ./sign_type_data/warning/00801_00002.png           warning
# 1172           ./sign_type_data/noentry/00293_00001.png           noentry
# 2351           ./sign_type_data/bicycle/00741_00002.png           bicycle
# 1852           ./sign_type_data/warning/00260_00000.png           warning
# 300          ./sign_type_data/noparking/00799_00000.png         noparking
# 2617  ./sign_type_data/trafficdirective/01957_00001.png  trafficdirective
# 748         ./sign_type_data/roundabout/00099_00002.png        roundabout
# 3221          ./sign_type_data/continue/01551_00002.png          continue
# 1825           ./sign_type_data/warning/01888_00002.png           warning
# 476    ./sign_type_data/traveldirection/00592_00002.png   traveldirection
# 3168          ./sign_type_data/crossing/00790_00002.png          crossing
# 735         ./sign_type_data/roundabout/00809_00000.png        roundabout
# 18             ./sign_type_data/giveway/00066_00001.png           giveway
#
# [3699 rows x 2 columns]

# %%
# Generate two data frames for training and validation
first_split = data.sample(frac=0.8).reset_index()
# print(first_split)
second_split= data.drop(first_split.index)
# print(second_split)

print('Train size: {}, Test size: {}'.format(first_split.shape[0], second_split.shape[0] ) )
N_train_images = first_split.shape[0]
N_val_images = second_split.shape[0]
# Out:
# Train size: 2959, Test size: 740

# %%
from sklearn.model_selection import train_test_split

train_df, validation_df = train_test_split(data, test_size=0.2)

# %%
batch_size = 16

# %%
def calculate_losses(model_in, data_generator_in, N_images, batch_size_):
    loss_hold = []
    acc_hold = []
    batches = 0
    
    # iterate over each batch
    for x,y in data_generator_in:
        loss, acc = model_in.evaluate(x, y, verbose=0)
        loss_hold.append(loss)
        acc_hold.append(acc)
        batches += 1
        if batches >= N_images / batch_size_:
            # we need to break the loop by hand because
            # the generator loops indefinitely
            break
            
    return np.mean(loss_hold), np.mean(acc_hold)

# %%
def train_model(model_, train_generator_in, validation_generator_in, num_epoch=50, verbose=False):
    res = []
    for e in range(num_epoch):
        # print('Epoch', e)
        batches = 0

        loss_ = []
        acc_ = []

         # iterate over each batch
        for x,y in train_generator_in:
            loss, acc = model_.train_on_batch(x, y) # Update weights and return train loss, acc per batch
            loss_.append(loss)
            acc_.append(acc)
            batches += 1
            if batches >= N_train_images / batch_size:
                # we need to break the loop by hand because
                # the generator loops indefinitely
                break
        loss_ = np.mean(loss_)
        acc_ = np.mean(acc_)

        loss, acc = calculate_losses(model_, validation_generator_in, N_val_images, batch_size)
        if verbose:
            print("Training epoch {}: Loss = {}, Accuracy = {}".format(e, loss_, acc_))
            print("Validation epoch {}: Loss = {}, Accuracy = {}".format(e, loss, acc))

        res.append((e, loss_, acc_, loss, acc))
    return np.asarray(res)

# %%
def plot_results(res):
    plt.figure(figsize=(12,4))
    plt.subplot(1,2,1)
    plt.plot(res[:,0], res[:,1], 'r-')
    plt.plot(res[:,0], res[:,3], 'b-')
    plt.legend(['Train', 'Validation'])
    plt.xlabel('epoch')
    plt.ylabel('Loss')
    plt.ylim([0, np.max([5., np.max(res[:,1]), np.max(res[:,3])])])

    plt.subplot(1,2,2)
    plt.plot(res[:,0], res[:,2], 'r-')
    plt.plot(res[:,0], res[:,4], 'b-')
    plt.legend(['Train', 'Validation'])
    plt.xlabel('epoch')
    plt.ylabel('Accuracy')
    plt.ylim([0, np.max([1., np.max(res[:,2]), np.max(res[:,4])])])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')
val_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

batch_size = 16

train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_df,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size,
        class_mode='categorical')

validation_generator = val_datagen.flow_from_dataframe(
        dataframe=validation_df,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size,
        class_mode='categorical')
# Out:
# Found 2959 validated image filenames belonging to 16 classes.
# Found 740 validated image filenames belonging to 16 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Lambda, Input
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.metrics import categorical_accuracy
from tensorflow.keras import regularizers, optimizers

model_cnn = Sequential()

# input
model_cnn.add(Input(shape=(28, 28, 3)))
model_cnn.add(Lambda(lambda x: tf.expand_dims(x[:,:,:,0], -1, name=None))) 
# this is a workaround. Dataloader automatically read one channel image as 3 channel 
#and we use Lambda layer to revert this back. Lambda layer can be used for operation 
#that does not involve trainianble weights

# Conv Layer 1
model_cnn.add(Conv2D(32, (3, 3),kernel_regularizer=regularizers.l2(0.001)))
model_cnn.add(Activation('relu'))
model_cnn.add(MaxPooling2D(pool_size=(2, 2)))

# Conv Layer 2 (no pooling)
model_cnn.add(Conv2D(32, (3, 3),kernel_regularizer=regularizers.l2(0.001)))
model_cnn.add(Activation('relu'))

# Conv Layer 3
model_cnn.add(Conv2D(64, (3, 3)))
model_cnn.add(Activation('relu'))
model_cnn.add(MaxPooling2D(pool_size=(2, 2)))

# MLP
model_cnn.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model_cnn.add(Dense(64))
model_cnn.add(Activation('relu'))
model_cnn.add(Dropout(0.5))
model_cnn.add(Dense(16))
model_cnn.add(Activation('softmax'))

sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model_cnn.compile(loss='categorical_crossentropy',
              optimizer=sgd,
              metrics=[categorical_accuracy])

# save the weights so that we can start from the same place when tring different configurations
model_cnn.save_weights('model2-1.h5')

model_cnn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_1 (Lambda)            (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# activation_5 (Activation)    (None, 26, 26, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 32)        9248
# _________________________________________________________________
# activation_6 (Activation)    (None, 11, 11, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 9, 9, 64)          18496
# _________________________________________________________________
# activation_7 (Activation)    (None, 9, 9, 64)          0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                65600
# _________________________________________________________________
# activation_8 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                1040
# _________________________________________________________________
# activation_9 (Activation)    (None, 16)                0
# =================================================================
# Total params: 94,704
# Trainable params: 94,704
# Non-trainable params: 0
# _________________________________________________________________

# %%
res = train_model(model_cnn, train_generator, validation_generator, num_epoch=50, verbose=1)
plot_results(res)
# Out:
# Training epoch 0: Loss = 1.9906651973724365, Accuracy = 0.4047072231769562
# Validation epoch 0: Loss = 0.7188183817457645, Accuracy = 0.8218085169792175
# Training epoch 1: Loss = 0.740380048751831, Accuracy = 0.7876576781272888
# Validation epoch 1: Loss = 0.32934752074961965, Accuracy = 0.9242021441459656
# Training epoch 2: Loss = 0.49264201521873474, Accuracy = 0.8624549508094788
# Training epoch 41: Loss = 0.05388905107975006, Accuracy = 0.9899324178695679
# Validation epoch 41: Loss = 0.06377982169865294, Accuracy = 0.9906914830207825
# Training epoch 42: Loss = 0.05922475829720497, Accuracy = 0.9865540266036987
# Validation epoch 42: Loss = 0.08145164345648695, Accuracy = 0.9853723645210266
# Training epoch 43: Loss = 0.05399126559495926, Accuracy = 0.9885135293006897
# Validation epoch 43: Loss = 0.0768318052621598, Accuracy = 0.9893617033958435
# Training epoch 44: Loss = 0.04312989488244057, Accuracy = 0.9915540814399719
# Validation epoch 44: Loss = 0.09084263824402018, Accuracy = 0.9867021441459656
# Training epoch 45: Loss = 0.042909685522317886, Accuracy = 0.9929053783416748
# Validation epoch 45: Loss = 0.0787026796172908, Accuracy = 0.9893617033958435
# Training epoch 46: Loss = 0.048136577010154724, Accuracy = 0.9912612438201904
# Validation epoch 46: Loss = 0.08172604627907276, Accuracy = 0.9827127456665039
# Training epoch 47: Loss = 0.03912898525595665, Accuracy = 0.9935810565948486
# Validation epoch 47: Loss = 0.08755955123837958, Accuracy = 0.9840425252914429
# Training epoch 48: Loss = 0.04731738567352295, Accuracy = 0.9895270466804504
# Validation epoch 48: Loss = 0.07626299845411423, Accuracy = 0.9893617033958435
# Training epoch 49: Loss = 0.0351131446659565, Accuracy = 0.9956080913543701
# Validation epoch 49: Loss = 0.08196864399979724, Accuracy = 0.9893617033958435

# %%
test_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

batch_size_t = 1

# Here the validation is used for testing and this should be changes to a separate test set.
test_generator = train_datagen.flow_from_dataframe(
        dataframe=validation_df,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size_t,
        class_mode='categorical')
# Out:
# Found 740 validated image filenames belonging to 16 classes.

# %%
d = {'bicycle':0, 'continue':1, 'crossing':2, 'giveway':3, 'laneend':4, 'limitedtraffic':5, 'noentry':6, 'noparking':7, 'parking':8, 
     'rightofway':9, 'roundabout':10, 'speed':11, 'stop':12, 'trafficdirective':13, 'trafficdirection':14, 'warning':15}
data['labels_num'] = data['label'].map(d, na_action='ignore')

# %%
d_inv = {v: k for k, v in d.items()}
plt.figure(figsize=(16,4))
batches = 0
for x,y in test_generator:
        batches = batches + 1
        y_hat = model_cnn.predict(x, verbose=0)
        x = np.squeeze(x)
        if batches < 5:
            plt.subplot(1,5,batches)
            plt.imshow(x)
            plt.title("GT-{}, Pred-{}".format(d_inv[np.argmax(y[0])], d_inv[np.argmax(y_hat[0])] ))
            
        else:
            break
        
        plt.axis('off')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last', 
                                   rotation_range=15, width_shift_range=0.2, 
                                   height_shift_range=0.2)
val_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

batch_size = 16

train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_df,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size,
        class_mode='categorical')

validation_generator = val_datagen.flow_from_dataframe(
        dataframe=validation_df,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size,
        class_mode='categorical')
# Out:
# Found 2959 validated image filenames belonging to 16 classes.
# Found 740 validated image filenames belonging to 16 classes.

# %%
model_cnn.load_weights('model2-1.h5')

res = train_model(model_cnn, train_generator, validation_generator, num_epoch=150, verbose=1)
plot_results(res)
# Out:
# Training epoch 0: Loss = 2.644960403442383, Accuracy = 0.17644144594669342
# Validation epoch 0: Loss = 2.484355906222729, Accuracy = 0.19015957415103912
# Training epoch 1: Loss = 2.3690097332000732, Accuracy = 0.2683333456516266
# Validation epoch 1: Loss = 1.9246992938061978, Accuracy = 0.4348404109477997
# Training epoch 2: Loss = 2.0707905292510986, Accuracy = 0.36925676465034485
# Validation epoch 2: Loss = 1.511515665561595, Accuracy = 0.6077127456665039
# Training epoch 3: Loss = 1.8045614957809448, Accuracy = 0.45218467712402344
# Validation epoch 3: Loss = 0.9883295849282691, Accuracy = 0.7406914830207825
# Training epoch 4: Loss = 1.5821818113327026, Accuracy = 0.5219594836235046
# Validation epoch 4: Loss = 0.8546655114660872, Accuracy = 0.7859042286872864
# Training epoch 5: Loss = 1.3392066955566406, Accuracy = 0.5965090394020081
# Validation epoch 5: Loss = 0.5898472866479386, Accuracy = 0.8164893388748169
# Training epoch 6: Loss = 1.1721346378326416, Accuracy = 0.6493918895721436
# Validation epoch 6: Loss = 0.5160504186407049, Accuracy = 0.8404255509376526
# Training epoch 7: Loss = 1.049785852432251, Accuracy = 0.6853153109550476
# Validation epoch 7: Loss = 0.4260846363737228, Accuracy = 0.8696808218955994
# Training epoch 8: Loss = 0.9357467293739319, Accuracy = 0.7251125574111938
# Validation epoch 8: Loss = 0.34511300017859076, Accuracy = 0.9255319237709045
# Training epoch 9: Loss = 0.8489917516708374, Accuracy = 0.7384459376335144
# Validation epoch 9: Loss = 0.3592061790380072, Accuracy = 0.9109042286872864
# Training epoch 10: Loss = 0.817876398563385, Accuracy = 0.7601576447486877
# Validation epoch 10: Loss = 0.38482930828282175, Accuracy = 0.8789893388748169
# Training epoch 11: Loss = 0.8124130368232727, Accuracy = 0.7597072124481201
# Validation epoch 11: Loss = 0.28887711069051253, Accuracy = 0.9242021441459656
# Training epoch 12: Loss = 0.7760750651359558, Accuracy = 0.7808333039283752
# Validation epoch 12: Loss = 0.35759989711198403, Accuracy = 0.897606372833252
# Training epoch 13: Loss = 0.7141280174255371, Accuracy = 0.7957658171653748
# Validation epoch 13: Loss = 0.2895403486934114, Accuracy = 0.9295212626457214
# Training epoch 14: Loss = 0.6861175298690796, Accuracy = 0.8092793226242065
# Validation epoch 14: Loss = 0.2550750274924522, Accuracy = 0.9454787373542786
# Training epoch 15: Loss = 0.6323719620704651, Accuracy = 0.8134909868240356
# Validation epoch 15: Loss = 0.266770047393251, Accuracy = 0.9614361524581909
# Training epoch 16: Loss = 0.6176584362983704, Accuracy = 0.8250450491905212
# Validation epoch 16: Loss = 0.24124083160719972, Accuracy = 0.9375
# Training epoch 17: Loss = 0.6279237270355225, Accuracy = 0.8353604078292847
# Validation epoch 17: Loss = 0.2642202396342095, Accuracy = 0.9468085169792175
# Training epoch 18: Loss = 0.6083245873451233, Accuracy = 0.8358333110809326
# Validation epoch 18: Loss = 0.3141378766678749, Accuracy = 0.9308510422706604
# Training epoch 19: Loss = 0.5731196999549866, Accuracy = 0.8449774384498596
# Validation epoch 19: Loss = 0.27797612500317553, Accuracy = 0.9468085169792175
# Validation epoch 134: Loss = 0.16279789139615727, Accuracy = 0.9853723645210266
# Training epoch 135: Loss = 0.29699355363845825, Accuracy = 0.9412387609481812
# Validation epoch 135: Loss = 0.16272600074397756, Accuracy = 0.9853723645210266
# Training epoch 136: Loss = 0.28676414489746094, Accuracy = 0.9438738822937012
# Validation epoch 136: Loss = 0.1727329766813745, Accuracy = 0.977393627166748
# Training epoch 137: Loss = 0.2720991373062134, Accuracy = 0.947545051574707
# Validation epoch 137: Loss = 0.14052516919501284, Accuracy = 0.9853723645210266
# Training epoch 138: Loss = 0.29976677894592285, Accuracy = 0.9374774694442749
# Validation epoch 138: Loss = 0.19776195129181476, Accuracy = 0.9760638475418091
# Training epoch 139: Loss = 0.3039912283420563, Accuracy = 0.939639687538147
# Validation epoch 139: Loss = 0.16929804232526333, Accuracy = 0.9853723645210266
# Training epoch 140: Loss = 0.2806287109851837, Accuracy = 0.9440540075302124
# Validation epoch 140: Loss = 0.16266893611309377, Accuracy = 0.980053186416626
# Training epoch 141: Loss = 0.27500882744789124, Accuracy = 0.9489864706993103
# Validation epoch 141: Loss = 0.15246805865713892, Accuracy = 0.980053186416626
# Training epoch 142: Loss = 0.2663150727748871, Accuracy = 0.9500450491905212
# Validation epoch 142: Loss = 0.16011485346454254, Accuracy = 0.9827127456665039
# Training epoch 143: Loss = 0.2523767352104187, Accuracy = 0.9497297406196594
# Validation epoch 143: Loss = 0.17111807792110645, Accuracy = 0.9867021441459656
# Training epoch 144: Loss = 0.2786993980407715, Accuracy = 0.9466215968132019
# Validation epoch 144: Loss = 0.1341664269566536, Accuracy = 0.9853723645210266
# Training epoch 145: Loss = 0.26754000782966614, Accuracy = 0.9517567157745361
# Validation epoch 145: Loss = 0.1596008838808283, Accuracy = 0.9840425252914429
# Training epoch 146: Loss = 0.28654587268829346, Accuracy = 0.9421846866607666
# Validation epoch 146: Loss = 0.14627059723468536, Accuracy = 0.9840425252914429
# Training epoch 147: Loss = 0.2751850187778473, Accuracy = 0.9466666579246521
# Validation epoch 147: Loss = 0.16472635957154821, Accuracy = 0.9827127456665039
# Training epoch 148: Loss = 0.28273528814315796, Accuracy = 0.943648636341095
# Validation epoch 148: Loss = 0.1860146532033352, Accuracy = 0.9813829660415649
# Training epoch 149: Loss = 0.24249958992004395, Accuracy = 0.9534459114074707
# Validation epoch 149: Loss = 0.20348132068806507, Accuracy = 0.9707446694374084

# %%
from PIL import Image
import pandas as pd
import glob
image_list = []
i = 0
for filepath in glob.glob('./sign_type_data_test/*/*.png', recursive=True): #assuming gif
    newsize = (28,28)
    img = Image.open(filepath).convert('L').resize(newsize)
    path = ('./processed_sign_type_data_test/'+str(i)+'.png')
    img.save(path, 'png')
    filename = path
    label = filepath.split("/")[-2]
#     print(filepath, filename, label)
    image_list.append((filename, label))
    i = i + 1
    
# Create a data frame
signtype_test_data = pd.DataFrame(data=image_list, columns=['image_path', 'label'])

# %%
test_datagen = ImageDataGenerator(rescale=1./255, data_format='channels_last')

batch_size_t = 1

# Here the validation is used for testing and this should be changes to a separate test set.
test_generator = train_datagen.flow_from_dataframe(
        dataframe=signtype_test_data,
        directory='./',
        x_col="image_path",
        y_col="label",
        target_size=(28, 28),
        batch_size=batch_size_t,
        class_mode='categorical')
# Out:
# Found 409 validated image filenames belonging to 16 classes.

# %%
d = {'bicycle':0, 'continue':1, 'crossing':2, 'giveway':3, 'laneend':4, 'limitedtraffic':5, 'noentry':6, 'noparking':7, 'parking':8, 
     'rightofway':9, 'roundabout':10, 'speed':11, 'stop':12, 'trafficdirective':13, 'trafficdirection':14, 'warning':15}
data['labels_num'] = data['label'].map(d, na_action='ignore')

# %%
d_inv = {v: k for k, v in d.items()}
plt.figure(figsize=(16,4))
batches = 0
for x,y in test_generator:
        batches = batches + 1
        y_hat = model_cnn.predict(x, verbose=0)
        x = np.squeeze(x)
        if batches < 5:
            plt.subplot(1,5,batches)
            plt.imshow(x)
            plt.title("GT-{}, Pred-{}".format(d_inv[np.argmax(y[0])], d_inv[np.argmax(y_hat[0])] ))
            
        else:
            break
        
        plt.axis('off')

# %%
model_cnn.load_weights('model2-1.h5')

res = train_model(model_cnn, train_generator, test_generator, num_epoch=50, verbose=1)
plot_results(res)
# Out:
# Training epoch 0: Loss = 2.6648998260498047, Accuracy = 0.17880630493164062
# Validation epoch 0: Loss = 2.875018903549681, Accuracy = 0.06382978707551956
# Training epoch 1: Loss = 2.50481915473938, Accuracy = 0.20911234617233276
# Validation epoch 1: Loss = 3.1613592695682606, Accuracy = 0.042553190141916275
# Training epoch 2: Loss = 2.127131700515747, Accuracy = 0.3534114956855774
# Validation epoch 2: Loss = 2.8638099837810436, Accuracy = 0.12765957415103912
# Training epoch 3: Loss = 1.7905250787734985, Accuracy = 0.4578537344932556
# Validation epoch 3: Loss = 2.9621519050065506, Accuracy = 0.1489361673593521
# Training epoch 4: Loss = 1.5513510704040527, Accuracy = 0.530463695526123
# Validation epoch 4: Loss = 2.5687028745070415, Accuracy = 0.19148936867713928
# Training epoch 5: Loss = 1.360109567642212, Accuracy = 0.5986526012420654
# Validation epoch 5: Loss = 3.0274783632856734, Accuracy = 0.25531914830207825
# Training epoch 6: Loss = 1.2203593254089355, Accuracy = 0.6426165699958801
# Validation epoch 6: Loss = 2.423105421614774, Accuracy = 0.2978723347187042
# Training epoch 7: Loss = 1.0801893472671509, Accuracy = 0.672551691532135
# Validation epoch 7: Loss = 2.7809083651989064, Accuracy = 0.23404255509376526
# Training epoch 8: Loss = 1.007584810256958, Accuracy = 0.6932273507118225
# Validation epoch 8: Loss = 4.122797491385581, Accuracy = 0.19148936867713928
# Training epoch 9: Loss = 0.931552529335022, Accuracy = 0.7132048010826111
# Validation epoch 9: Loss = 3.5546770845638944, Accuracy = 0.3191489279270172
# Training epoch 10: Loss = 0.8572241067886353, Accuracy = 0.7561553120613098
# Validation epoch 10: Loss = 3.3680579215288162, Accuracy = 0.3191489279270172
# Training epoch 11: Loss = 0.8737591505050659, Accuracy = 0.7458930015563965
